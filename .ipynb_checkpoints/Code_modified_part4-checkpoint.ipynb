# %% [markdown]
# # Part 1

# %%
import pandas as pd

# %%
def file_to_df(file_path):
    """
    Read data from a file, process it, and create a Pandas DataFrame.

    Parameters:
    file_path (str): The path to the file containing the data.

    Returns:
    DataFrame: A DataFrame containing processed data with columns 'x' and 'y'.
    """

    # Opens the file using file_path function. 
    with open(file_path, 'r', encoding='utf-8') as file:
        # Reads lines of file using readlines()
        lines = file.readlines()
        # So, the entire expression takes each line, removes leading/trailing whitespace,
        # splits it into parts based on spaces (up to 2 splits), and then extracts the first two parts.
        # The result is a list of pairs of values from each line in the lines list. 
        data = [line.strip().split(' ', maxsplit=2)[:2] for line in lines]

    # Creating dataframe from the data list with 2 columns, x and y.
    df = pd.DataFrame(data, columns=['x', 'y'])

    # Drop rows where value for y = None 
    df = df.dropna(subset=['y'])

    # Convert the data type of columns 'x' and 'y' to strings
    df['x'] = df['x'].astype(str)
    df['y'] = df['y'].astype(str)

    # Display the dataframe
    return df

# file_to_df function called with the file path
file_path_train_es = 'Data/ES/train'

# Stores resulting dataframe in df_train_es
df_train_es = file_to_df(file_path_train_es)

# %%
def count_y(df, y_value):
    """
    Count the occurrences of a specific value in the 'y' column of a DataFrame.

    Parameters:
    df (DataFrame): The DataFrame containing the data.
    y_value: The value for which the count is to be determined.

    Returns:
    int: The count of occurrences of the specified y_value.
    """

    # Calculate the count of each unique value in the 'y' column and convert it to a dictionary.
    unique_counts = df['y'].value_counts().to_dict()

    # Return the count of occurrences of the specified y_value
    print("unique counts:", unique_counts)
    return unique_counts[y_value]

# %%
def y_star_with_smallest_count(df):
    """
    Find the unique value(s) in the 'y_star' column of a DataFrame that have the smallest count.

    Parameters:
    df (DataFrame): The DataFrame containing the data.

    Returns:
    The unique value(s) in the 'y_star' column with the smallest count.
    """

    # Calculate the count of each unique value in the 'y_star' column and convert it to a dictionary.
    unique_counts = df['y_star'].value_counts().to_dict()
    
    # Find the smallest count value among the unique counts.
    min_count = min(unique_counts.values())

    # Construct a list of unique value(s) with the smallest count.
    y_with_min_count = [key for key, value in unique_counts.items() if value == min_count]

    # Return the first value from the list (if there are multiple values with the smallest count).
    return y_with_min_count[0]

# %%
def create_df_filtered_for_y_value(df, y_value):
    """
    Create a filtered DataFrame containing rows where the 'y' column matches a specific value.

    Parameters:
    df (DataFrame): The original DataFrame containing the data.
    y_value: The value to filter rows based on in the 'y' column.

    Returns:
    DataFrame: A new DataFrame with rows filtered for the specified y_value in the 'y' column.
    """

    return df[df['y'] == y_value]

# %%
def create_df_x_count_y_to_x(df):
    """
    Create a DataFrame that shows the count of occurrences of each 'x' value in the original DataFrame.

    Parameters:
    df (DataFrame): The original DataFrame containing the data.

    Returns:
    DataFrame: A new DataFrame with 'x' values and their corresponding counts.
    """

    # Calculate the count of occurrences of each 'x' value and reset the index.
    df_x_count_y_to_x = df['x'].value_counts().reset_index()

    # Rename columns to 'x' and 'count_y_to_x' for clarity.
    df_x_count_y_to_x.columns = ['x', 'count_y_to_x']

    return df_x_count_y_to_x

# %%
def create_ls_of_all_y_values(df):
    """
    Create a list of all unique values in the 'y' column of the DataFrame.

    Parameters:
    df (DataFrame): The DataFrame containing the data.

    Returns:
    list: A list containing all unique values in the 'y' column.
    """

    # Retrieve the unique values from the 'y' column.
    unique_values = df['y'].unique()

    # Return the list of unique 'y' values.
    return unique_values
    
print(create_ls_of_all_y_values(df_train_es))
# Out:
# ['O' 'B-positive' 'B-negative' 'B-neutral' 'I-neutral' 'I-positive'
#  'I-negative']

# %%
def create_df_e_x_y_train(train_df, y_value):
    """
    Create a DataFrame containing conditional probabilities and 'y' values for specific conditions.

    Parameters:
    train_df (DataFrame): The training DataFrame containing the data.
    y_value: The specific 'y' value for which conditional probabilities are calculated.

    Returns:
    DataFrame: A new DataFrame with conditional probabilities and 'y' values.
    """

    # Filter the training DataFrame for the specified y_value.
    df_train_filtered_for_y = create_df_filtered_for_y_value(train_df, y_value)

    # Create a DataFrame showing the count of occurrences of each 'x' value for the specified y_value.
    df_e_x_y_train = create_df_x_count_y_to_x(df_train_filtered_for_y)

    # Conditional probability formula - P(x|y) = P(x ∩ y) / P(y)
    # Calculate conditional probabilities 'e(x|y)' by dividing
    # the count of occurrences of each 'x' value for the specific 'y' value.
    # by the count of occurrences of the specific y_value
    df_e_x_y_train['e(x|y)'] = df_e_x_y_train['count_y_to_x'] / (count_y(train_df, y_value))

    # Add 'y' column to the DataFrame with the specified y_value.
    df_e_x_y_train['y'] = y_value
    
    return df_e_x_y_train

# Create a DataFrame containing conditional probabilities for a specific 'y' value.
df_e_x_y_train_for_I_neutral = create_df_e_x_y_train(df_train_es, "B-positive")

# Print the DataFrame showing conditional probabilities.
print(df_e_x_y_train_for_I_neutral)

# Calculate and print the sum of conditional probabilities from the DataFrame. 
# Should add to 1 according to the characteristics of a probability distribution.
print(df_e_x_y_train_for_I_neutral['e(x|y)'].sum())
# Out:
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
#                x  count_y_to_x    e(x|y)           y
# 0         comida           169  0.145690  B-positive
# 1       servicio           122  0.105172  B-positive
# 2    restaurante            46  0.039655  B-positive
# 3          trato            44  0.037931  B-positive
# 4       ambiente            33  0.028448  B-positive
# ..           ...           ...       ...         ...
# 280       dorada             1  0.000862  B-positive
# 281      detalle             1  0.000862  B-positive
# 282   cantidades             1  0.000862  B-positive
# 283       Atteca             1  0.000862  B-positive
# 284        menus             1  0.000862  B-positive
#
# [285 rows x 4 columns]
# 1.0000000000000002

# %%
def create_df_e_x_y_test(test_df, y_value, train_df):
    """
    Create a DataFrame containing conditional probabilities 'e(x|y)' for a specific 'y' value using test and training data.

    Parameters:
    test_df (DataFrame): The test DataFrame containing the data to be evaluated.
    y_value: The specific 'y' value for which conditional probabilities are calculated.
    train_df (DataFrame): The training DataFrame containing the data used for reference.

    Returns:
    DataFrame: A new DataFrame with 'x' values, calculated conditional probabilities 'e(x|y)', and a sum of probabilities.
    """

    # Initializing k = 1
    k = 1

    # Filtering the test DataFrame for the specified 'y' value
    df_test_filtered_for_y = create_df_filtered_for_y_value(test_df, y_value)

    # Creating a DataFrame with count of occurrences of each 'x' value for the specified 'y' value
    # for the filtered test DataFrame
    df_e_x_y_test = create_df_x_count_y_to_x(df_test_filtered_for_y)

    # Calculating the total count of 'y' values plus a constant k (1)
    count_y_plus_k = count_y(test_df, y_value) + k

    # Extracting the 'x' values from the training DataFrame
    train_df_x_values = train_df['x'].tolist()

    # Handling unknown 'x' values by replacing them with "#UNK#" if not present in the training set
    df_e_x_y_test['x'] = df_e_x_y_test['x'].apply(lambda x: x if x in train_df_x_values else "#UNK#")

    # Calculating conditional probabilities 'e(x|y)' based on the 'x' values
    df_e_x_y_test['e(x|y)'] = df_e_x_y_test.apply(lambda row: (row['count_y_to_x'] / count_y_plus_k) if row['x'] != '#UNK#' else (k / count_y_plus_k), axis=1)

    # Printing the sum of conditional probabilities
    # Should add to 1 according to the characteristics of the probability distribution
    print(df_e_x_y_test['e(x|y)'].sum())

    # Returning the DataFrame containing calculated conditional probabilities
    return df_e_x_y_test

# Define the file path for the test data
file_path_test_es = 'Data/ES/dev.out'

# Load the test data from the specified file path into a DataFrame
df_test_es = file_to_df(file_path_test_es)

# Create a DataFrame containing conditional probabilities for a specific 'y' value using test and training data
df_e_x_y_test_for_I_neutral = create_df_e_x_y_test(df_test_es, "B-positive", df_train_es)

# Print the DataFrame showing calculated conditional probabilities
print(df_e_x_y_test_for_I_neutral)
# Out:
# unique counts: {'O': 3998, 'B-positive': 160, 'B-negative': 61, 'I-positive': 49, 'I-negative': 36, 'B-neutral': 8}
# 0.9937888198757765
#                x  count_y_to_x    e(x|y)
# 0       servicio            24  0.149068
# 1         comida            23  0.142857
# 2    restaurante             8  0.049689
# 3       ambiente             7  0.043478
# 4         platos             6  0.037267
# ..           ...           ...       ...
# 67      cocinero             1  0.006211
# 68        tartar             1  0.006211
# 69       postres             1  0.006211
# 70  localización             1  0.006211
# 71         comer             1  0.006211
#
# [72 rows x 3 columns]

# %%
def create_e_x_y_df_train_all_y_values(file_path):
    """
    Create a combined DataFrame of conditional probabilities 'e(x|y)' for all unique 'y' values in the provided dataset.

    Parameters:
    file_path (str): The file path to the dataset containing 'x' and 'y' values.

    Returns:
    DataFrame: A DataFrame containing calculated conditional probabilities for each 'x' value and unique 'y' value.
    """

    # Load the data from the specified file path into a DataFrame
    df_train = file_to_df(file_path)

    # Initialize an empty list to store DataFrames containing conditional probabilities
    ls_df_train = []

    # Create a list of all unique 'y' values in the DataFrame
    ls_y_values = create_ls_of_all_y_values(df_train)

    # Iterate through each unique 'y' value
    for y_value in ls_y_values:
        # Skip the loop iteration if y_value is None
        if y_value is not None:
            # Calculate conditional probabilities for the current 'y' value and add to the list
            df_e_x_y = create_df_e_x_y_train(df_train, y_value)
            # Append the conditional probability for that y value to the list
            ls_df_train.append(df_e_x_y)

    # Concatenate the list of DataFrames into a single DataFrame, combining the rows (stacking the DataFrames)
    combined_df_train = pd.concat(ls_df_train, axis=0)
    return combined_df_train

file_path_train_es = 'Data/ES/train'
print(create_e_x_y_df_train_all_y_values(file_path_train_es))
# Out:
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
#           x  count_y_to_x    e(x|y)           y
# 0         ,          1664  0.057310           O
# 1         .          1623  0.055898           O
# 2         y          1024  0.035268           O
# 3        de          1011  0.034820           O
# 4       que           845  0.029103           O
# ..      ...           ...       ...         ...
# 108    está             1  0.005848  I-negative
# 109    sopa             1  0.005848  I-negative
# 110  tabaco             1  0.005848  I-negative
# 111  gambas             1  0.005848  I-negative
# 112    pizz             1  0.005848  I-negative
#
# [5589 rows x 4 columns]

# %%
def create_df_x_to_y_star(file_path):

    # Calculate conditional probabilities for all 'y' values using the training data
    e_x_y_df_train = create_e_x_y_df_train_all_y_values(file_path)

    # Group by 'x' and find the maximum 'e(x|y)' value for each group
    df_x_to_y_star = e_x_y_df_train.groupby('x')['e(x|y)'].max().reset_index()

    # Find the corresponding 'y' values for the maximum 'e(x|y)' values
    df_x_to_y_star = pd.merge(df_x_to_y_star, e_x_y_df_train, on=['x', 'e(x|y)'])

    # Rename the columns
    df_x_to_y_star.columns = ['x', 'max_e(x|y)', 'count_y_to_x', 'y_star']

    # Return the resulting DataFrame
    return df_x_to_y_star

file_path_train_es = 'Data/ES/train'
create_df_x_to_y_star(file_path_train_es)
# Out:
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
#       x  max_e(x|y)  count_y_to_x      y_star
# 0     !    0.005442           158           O
# 1     "    0.011696             2  I-negative
# 2     %    0.000413            12           O
# 3     (    0.004512           131           O
# 4     )    0.004512           131           O
# ...  ..         ...           ...         ...
# 5035  “    0.003185             1  I-positive
# 5036  ”    0.003185             1  I-positive
# 5037  …    0.002625             1  B-negative
# 5038  ″    0.000034             1           O
# 5039  €    0.003185             1  I-positive
#
# [5040 rows x 4 columns]

# %%
def generate_y_values(file_path_dev_in, file_path_train, file_path_dev_p1_out):
    """
    Generate 'y' values using conditional probabilities and write the results to an output file.

    Parameters:
    file_path_dev_in (str): The file path to the input dataset containing 'x' values.
    file_path_train (str): The file path to the training dataset containing 'x' and 'y' values.
    file_path_dev_p1_out (str): The file path to write the generated 'y' values.

    Returns:
    None
    """
    
    # Generate a DataFrame using the create_df_x_to_y_star function
    df_train = create_df_x_to_y_star(file_path_train)

    # Convert the x values in df_train to a list
    x_values = df_train['x'].tolist()
    
    # The y_label that has the smallest count_y will generate the biggest k / count_y_plus_k,
    # which will give the maximum e(x|y), meaning that y_label is y_star
    y_label = y_star_with_smallest_count(df_train)
    
    # Open the input file for reading and use UTF-8 encoding
    with open(file_path_dev_in, 'r', encoding='utf-8') as file:

        # Read all lines from the file and store them in a list
        lines = file.readlines()

        # Iterate through each line in the list of lines
        for l in range(len(lines)):
            
            # Remove leading/trailing whitespace and store the current line
            line = lines[l].strip()

            # Check if the current line exists in the list of 'x_values'
            if line in x_values:

                # Get corresponding 'y_star' value(s) for the 'x' value in the current line
                possible_y_values = df_train[df_train['x'] == line]['y_star'].tolist()

                # Append the first 'y_star' value to the current line
                lines[l] = line + " " + possible_y_values[0]

                # Check if there are multiple 'y_star' values, indicating a potential issue
                if len(possible_y_values) != 1:
                    print("Something wrong: x_values in df_train not unique for some reason, for line:", l)
            
            # If the current line is not in 'x_values'
            else:
                 
                # Check if the line is not empty
                if line != "\n":

                    # Append the default 'y_label' to the current line
                    line = line + " " + y_label

                    # Update the current line in the list
                    lines[l] = line
    
    # Open the output file for writing using UTF-8 encoding
    with open(file_path_dev_p1_out, 'w', encoding='utf-8') as file:
        
        # Write each modified line back to the output file
        for line in lines:
            print(line)
            if line != "\n":
                file.write(line + '\n')
            else:
                file.write(line)


file_path_dev_in_es = 'Data/ES/dev.in'
file_path_train_es = 'Data/ES/train'
file_path_dev_p1_out_es = 'Data/ES/dev.p1.out'
generate_y_values(file_path_dev_in_es, file_path_train_es, file_path_dev_p1_out_es)
# Out:
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# unique counts: {'O': 29035, 'B-positive': 1160, 'B-negative': 381, 'I-positive': 314, 'I-negative': 171, 'B-neutral': 72, 'I-neutral': 43}
# Plato B-negative
# degustación I-positive
# : O
# un O
# poco O
# abundante O
# de I-positive
# más O
# , O
# pero I-neutral
# bien O
# cocinado O
# . O
#  I-neutral
# restaurante B-negative
# excelente O
# con I-neutral
# carne B-negative
# de I-positive
# alta O
# calidad I-positive
# . O
#  I-neutral
# Las O
# posibilidades I-neutral
# en I-neutral
# el I-neutral
# restaurante B-negative
# son O
# fundamentalmente I-neutral
# tres I-negative
# ; O
# carta B-negative
# normal O
# , O
# menú B-positive
# degustacion I-positive
# y O
# una O
# opción O
# intermedia I-neutral
# que O
# es O
# una O
# selección O
# de I-positive
# primeros O
# y O
# postres B-negative
# y O
# carta B-negative
# para O
# el I-neutral
# segundo B-negative
# . O
#  I-neutral
# No I-positive
# perderse I-neutral
# el I-neutral
# sorbete B-positive
# de I-positive
# mojito I-neutral
# . O
#  I-neutral
# para O
# mi O
# perfecto O
# ! O
#  I-neutral
# Devolucion I-neutral
# a I-neutral
# cocina B-neutral
# , O
# amabilidad O
# de I-positive
# camarera B-positive
# , O
# requerimiento I-neutral
# de I-positive
# cuenta B-neutral
# y O
# adios O
# . O
#  I-neutral
# Así O
# como O
# el I-neutral
# romesco I-neutral
# , O
# que O
# era O
# un O
# poco O
# " I-negative
# de I-positive
# bote O
# " I-negative
# . O
#  I-neutral
# Destacar I-neutral
# los O
# arroces B-positive
# , O
# la I-positive
# caldereta I-neutral
# de I-positive
# bogavante I-neutral
# , O
# las I-negative
# zamburiñas I-neutral
# al I-neutral
# horno I-positive
# y O
# los O
# platos B-negative
# de I-positive
# " I-negative
# picoteo I-neutral
# " I-negative
# y O
# los O
# pescados B-positive
# en I-neutral
# general O
# . O
#  I-neutral
# Somos O
# clientes O
# asiduos I-neutral
# . O
# segir I-neutral
# que O
# lo O
# bordais I-neutral
# GRACIAS I-neutral
# . O
#  I-neutral
# Pedimos O
# un O
# menú B-positive
# degustación I-positive
# y O
# todo I-negative
# buenísimo O
# . O
#  I-neutral
# Estaría I-neutral
# bien O
# mejorar O
# la I-positive
# calidad I-positive
# del I-negative
# vino B-negative
# . O
#  I-neutral
# Sin O
# duda O
# repetiremos O
# . O
#  I-neutral
# Estuve O
# este O
# sabado O
# pasado O
# cenando O
# y O
# he O
# de I-positive
# felicitar O
# tanto O
# al I-neutral
# restaurante B-negative
# como O
# al I-neutral
# camarero B-negative
# que O
# nos O
# atendio O
# y O
# yo I-negative
# elegí I-neutral
# churrasco I-neutral
# , O
# que O
# estaba O
# sensacional O
# , O
# y O
# con I-neutral
# patatas I-negative
# fritas I-negative
# caseras I-neutral
# ( O
# no O
# congeladas I-neutral
# ) O
# . O
#  I-neutral
# Buen O
# comer I-negative
# y O
# muy O
# buen O
# servicio B-positive
# . O
#  I-neutral
# he O
# ido O
# varias O
# veces O
# pero I-neutral
# el I-neutral
# sitio B-neutral
# es O
# para O
# turistas O
# y O
# aunque O
# la I-positive
# calidad I-positive
# es O
# buena O
# el I-neutral
# precio B-neutral
# es O
# exagerado O
# y O
# el I-neutral
# servicio B-positive
# deja O
# mucho I-negative
# que O
# desear O
# , O
# sobretodo O
# en I-neutral
# cuanto O
# a I-neutral
# las I-negative
# reservas I-neutral
# . O
#  I-neutral
# En B-negative
# la I-positive
# mesa B-negative
# que O
# nos O
# prepararon O
# caía I-neutral
# aigua I-neutral
# del I-negative
# techo I-neutral
# , O
# y O
# estabamos O
# pegados O
# a I-neutral
# la I-positive
# caleffacción I-neutral
# . O
#  I-neutral
# Los I-positive
# camareros B-negative
# son O
# atentos I-positive
# y O
# muy O
# amables I-positive
# , O
# el I-neutral
# menú B-positive
# calçotada B-positive
# es O
# interminable I-neutral
# ! O
#  I-neutral
# Lo I-positive
# recomiendo O
# , O
# no O
# les I-positive
# dejara I-neutral
# indiferente I-neutral
# . O
#  I-neutral
# Si O
# tienes O
# cuidado O
# con I-neutral
# lo O
# que O
# pides O
# puedes O
# comer I-negative
# muy O
# bien O
# sin I-negative
# dejarte I-neutral
# la I-positive
# cartera I-neutral
# . O
#  I-neutral

# %%
file_path_dev_p1_out_es = 'Data/ES/dev.p1.out'
file_dev_out_es = 'Data/ES/dev.out'
df_dev_p1_out_es = file_to_df(file_path_dev_p1_out_es)
df_dev_out_es = file_to_df(file_dev_out_es)
print(df_dev_p1_out_es.shape[0])
print(df_dev_out_es.shape[0])

df1 = df_dev_p1_out_es
df2 = df_dev_out_es

# Compare rows
comparison = df1.equals(df2)

# Get the count of rows that are the same
count_same = df1[df1.eq(df2).all(axis=1)].shape[0]

# Get the count of rows that are not the same
count_not_same = df1[df1.ne(df2).any(axis=1)].shape[0]

# Get the rows that are not the same
rows_not_same = df1[~df1.eq(df2).all(axis=1)]

total_number_of_correctly_predicted_entries = count_same
total_number_of_predicted_entities = df1.shape[0]
precision = total_number_of_correctly_predicted_entries / total_number_of_predicted_entities
print(precision)

# Display the results
# print("Comparison result:", comparison)
# print("Count of rows that are the same:", count_same)
# print("Count of rows that are not the same:", count_not_same)
# print("Rows that are not the same:\n", rows_not_same)
# Out:
# 4312
# 4312
# 0.6307977736549165

# %% [markdown]
# # Part 2

# %% [markdown]
# ## ES Dataset

# %%
import pandas as pd

# 1. Extracting data
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.read().strip().split('\n\n')
    return [sentence.split('\n') for sentence in data]

# Adjusting the paths for ES and RU datasets
train_data = load_data('Data/ES/train')
dev_in_data = load_data('Data/ES/dev.in')
with open('Data/ES/dev.out', 'r', encoding='utf-8') as f:
    dev_tags_actual = [sentence.split() for sentence in f.read().strip().split('\n\n')]

def compute_probabilities(data, state_list):
    # Initialize Count Dictionaries
    start_transition_count = {state: 0 for state in state_list}
    transition_count = {state: {state2: 0 for state2 in state_list} for state in state_list}
    emission_count = {state: {} for state in state_list}
    state_count = {state: 0 for state in state_list}

    for sentence in data:
        prev_state = None
        for line in sentence:
            word, state = line.strip().split()
            
            # Update start_transition_count for the first word-state pair in a sentence
            if prev_state is None:
                start_transition_count[state] += 1
            else:
                # Update transition_count for subsequent word-state pairs
                transition_count[prev_state][state] += 1

            # Update state_count and emission_count for every word-state pair
            state_count[state] += 1
            emission_count[state][word] = emission_count[state].get(word, 0) + 1
            prev_state = state

    total_sentences = len(data)
    
    # Compute Probabilities
    start_transition_prob = {state: count / total_sentences for state, count in start_transition_count.items()}
    transition_prob = {state: {state2: count2 / state_count[state] for state2, count2 in count.items()} for state, count in transition_count.items()}
    emission_prob = {state: {word: count / state_count[state] for word, count in state_emission_count.items()} for state, state_emission_count in emission_count.items()}

    return start_transition_prob, transition_prob, emission_prob


def viterbi(obs, states, start_p, trans_p, emit_p):
    V = [{}]
    
    # Initialization step
    for st in states:
        V[0][st] = {"prob": start_p.get(st, 0) * emit_p[st].get(obs[0], 0.00001), "prev": None}
    
    # Recursive step
    for t in range(1, len(obs)):
        V.append({})
        for st in states:
            # Get max transition probability and corresponding previous state in one go
            max_trans_prob, prev_st_selected = max(
                (V[t-1][prev_st]["prob"] * trans_p[prev_st].get(st, 0.00001), prev_st) for prev_st in states
            )
            
            max_prob = max_trans_prob * emit_p[st].get(obs[t], 0.00001)  # Added a small value to avoid multiplying by 0
            V[t][st] = {"prob": max_prob, "prev": prev_st_selected}
    
    # Termination step
    opt = []
    max_prob, previous = max((value["prob"], st) for st, value in V[-1].items())
    opt.append(previous)

    # Backtrack step
    for t in range(len(V) - 2, -1, -1):
        opt.insert(0, V[t + 1][previous]["prev"])
        previous = V[t + 1][previous]["prev"]
    
    return opt



def extract_entities_from_tags(tags):
    entities = []
    entity = []
    for tag in tags:
        if tag.startswith("B-"):
            if entity:
                entities.append(tuple(entity))
                entity = []
            entity.append(tag)
        elif tag.startswith("I-"):
            entity.append(tag)
        else:
            if entity:
                entities.append(tuple(entity))
                entity = []
    if entity:
        entities.append(tuple(entity))
    return set(entities)

TP = 0
FP = 0
FN = 0

states = {}
observations = {}

for sentence in train_data:
    for line in sentence:
        word, tag = line.strip().split()
        states[tag] = states.get(tag, 0) + 1
        if tag not in observations:
            observations[tag] = {}
        observations[tag][word] = observations[tag].get(word, 0) + 1

state_list = list(states.keys())

state_list = list(states.keys())
start_transition_prob, transition_prob, emission_prob = compute_probabilities(train_data, state_list)
predicted_tags_viterbi = [viterbi([word.split()[0] for word in sentence], state_list, start_transition_prob, transition_prob, emission_prob) for sentence in dev_in_data]

for pred, actual in zip(predicted_tags_viterbi, dev_tags_actual):
    predicted_entities = extract_entities_from_tags(pred)
    actual_entities = extract_entities_from_tags(actual)
    TP += len(predicted_entities.intersection(actual_entities))
    FP += len(predicted_entities - actual_entities)
    FN += len(actual_entities - predicted_entities)

precision = TP / (TP + FP)
recall = TP / (TP + FN)
f_score = 2 * precision * recall / (precision + recall)

print("Precision:", precision)
print("Recall:", recall)
print("F-score:", f_score)
# Out:
# Precision: 0.5517241379310345
# Recall: 0.42780748663101603
# F-score: 0.4819277108433735

# %%
predicted_tags_viterbi
# Out:
# [['B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-positive', 'I-positive', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'B-negative', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'B-positive', 'O'],
#  ['O', 'B-positive', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-neutral',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'B-positive', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'B-positive', 'O'],
#  ['B-positive', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-positive', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-positive', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'B-positive', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'I-positive', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'B-positive', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-positive', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'B-positive', 'O'],
#  ['O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'I-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-positive',
#   'I-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-positive',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'I-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-positive', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'I-negative',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-positive', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-positive', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-positive',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
dev_in_data
# Out:
# [['Plato',
#   'degustación',
#   ':',
#   'un',
#   'poco',
#   'abundante',
#   'de',
#   'más',
#   ',',
#   'pero',
#   'bien',
#   'cocinado',
#   '.'],
#  ['restaurante', 'excelente', 'con', 'carne', 'de', 'alta', 'calidad', '.'],
#  ['Las',
#   'posibilidades',
#   'en',
#   'el',
#   'restaurante',
#   'son',
#   'fundamentalmente',
#   'tres',
#   ';',
#   'carta',
#   'normal',
#   ',',
#   'menú',
#   'degustacion',
#   'y',
#   'una',
#   'opción',
#   'intermedia',
#   'que',
#   'es',
#   'una',
#   'selección',
#   'de',
#   'primeros',
#   'y',
#   'postres',
#   'y',
#   'carta',
#   'para',
#   'el',
#   'segundo',
#   '.'],
#  ['No', 'perderse', 'el', 'sorbete', 'de', 'mojito', '.'],
#  ['para', 'mi', 'perfecto', '!'],
#  ['Devolucion',
#   'a',
#   'cocina',
#   ',',
#   'amabilidad',
#   'de',
#   'camarera',
#   ',',
#   'requerimiento',
#   'de',
#   'cuenta',
#   'y',
#   'adios',
#   '.'],
#  ['Así',
#   'como',
#   'el',
#   'romesco',
#   ',',
#   'que',
#   'era',
#   'un',
#   'poco',
#   '"',
#   'de',
#   'bote',
#   '"',
#   '.'],
#  ['Destacar',
#   'los',
#   'arroces',
#   ',',
#   'la',
#   'caldereta',
#   'de',
#   'bogavante',
#   ',',
#   'las',
#   'zamburiñas',
#   'al',
#   'horno',
#   'y',
#   'los',
#   'platos',
#   'de',
#   '"',
#   'picoteo',
#   '"',
#   'y',
#   'los',
#   'pescados',
#   'en',
#   'general',
#   '.'],
#  ['Somos',
#   'clientes',
#   'asiduos',
#   '.',
#   'segir',
#   'que',
#   'lo',
#   'bordais',
#   'GRACIAS',
#   '.'],
#  ['Pedimos', 'un', 'menú', 'degustación', 'y', 'todo', 'buenísimo', '.'],
#  ['Estaría', 'bien', 'mejorar', 'la', 'calidad', 'del', 'vino', '.'],
#  ['Sin', 'duda', 'repetiremos', '.'],
#  ['Estuve',
#   'este',
#   'sabado',
#   'pasado',
#   'cenando',
#   'y',
#   'he',
#   'de',
#   'felicitar',
#   'tanto',
#   'al',
#   'restaurante',
#   'como',
#   'al',
#   'camarero',
#   'que',
#   'nos',
#   'atendio',
#   'y',
#   'por',
#   'supuesto',
#   'la',
#   'comida',
#   '.'],
#  ['A', 'mejorar', 'baños', '.'],
#  ['Nosotros',
#   'ya',
#   'ibamos',
#   'con',
#   'la',
#   'idea',
#   'de',
#   'cenar',
#   'pizza',
#   ',',
#   'y',
#   'nos',
#   'sorprendió',
#   'ver',
#   'que',
#   'había',
#   'poquita',
#   'variedad',
#   '...'],
#  ['Tal',
#   'vez',
#   'la',
#   'única',
#   'pega',
#   '(',
#   'para',
#   'mi',
#   'gusto',
#   ')',
#   'es',
#   'que',
#   'la',
#   'parrillada',
#   'de',
#   'carne',
#   'no',
#   'era',
#   'muy',
#   'grande',
#   '(',
#   'aunque',
#   'sí',
#   'es',
#   'cierto',
#   'que',
#   'te',
#   'dejaban',
#   'repetir',
#   'calçots',
#   'y',
#   'que',
#   'casi',
#   'todo',
#   'el',
#   'mundo',
#   'estaba',
#   'lleno',
#   'ya',
#   ')',
#   '.'],
#  ['Menú',
#   'calçotada',
#   'muy',
#   'bien',
#   ',',
#   'dejando',
#   'repetir',
#   ',',
#   'buena',
#   'relación',
#   'calidad-precio-calidad',
#   '.'],
#  ['Interesante',
#   'restaurante',
#   'en',
#   'el',
#   'Born',
#   ',',
#   'gran',
#   'calidad',
#   'en',
#   'el',
#   'producto',
#   'utilizado',
#   ',',
#   'tal',
#   'vez',
#   'el',
#   'único',
#   'pero',
#   'sería',
#   'que',
#   'la',
#   'sala',
#   'es',
#   'un',
#   'poco',
#   'ruidosa',
#   'y',
#   'las',
#   'mesas',
#   'están',
#   'un',
#   'poco',
#   'próximas',
#   'entre',
#   'sí',
#   '.'],
#  ['Un', 'saludo', '.'],
#  ['Servicio',
#   '-',
#   '4',
#   '(',
#   'Nos',
#   'sentimos',
#   'un',
#   'poco',
#   'invisibles',
#   'por',
#   'el',
#   'personal',
#   ',',
#   'simplemente',
#   'se',
#   'dedicaron',
#   'a',
#   'servir',
#   'la',
#   'comida',
#   '.'],
#  ['Muy',
#   'bueno',
#   ',',
#   'calidad',
#   ',',
#   'servicio',
#   'que',
#   'justifican',
#   'su',
#   'precio',
#   '.'],
#  ['La', 'decoración', 'bastante', 'conseguida', '.'],
#  ['Para',
#   'finalizar',
#   'con',
#   'los',
#   'previos',
#   'antes',
#   'de',
#   'entrar',
#   'con',
#   'la',
#   'comida',
#   'un',
#   'comentario',
#   ':',
#   'un',
#   'poquito',
#   'de',
#   'musica',
#   'de',
#   'ambiente',
#   'daria',
#   'intimidad',
#   ',',
#   'se',
#   'oia',
#   'todo',
#   'lo',
#   'que',
#   'se',
#   'decia',
#   'en',
#   'las',
#   'otras',
#   '5',
#   'mesas',
#   'que',
#   'estaban',
#   'ocupadas',
#   '(',
#   'todas',
#   'ellas',
#   'con',
#   'parejas',
#   'con',
#   'cupones',
#   'de',
#   'descuento',
#   'como',
#   'nosotros',
#   ')',
#   '.'],
#  ['El', 'trato', 'amable', ',', 'y', 'el', 'servicio', 'rápido', '.'],
#  ['Al',
#   'principio',
#   'nos',
#   'parecieron',
#   'un',
#   'poco',
#   'bruscos',
#   'y',
#   'habiendo',
#   'reservado',
#   'nos',
#   'iban',
#   'a',
#   'dar',
#   'la',
#   'peor',
#   'mesa',
#   'del',
#   'restaurante',
#   '.'],
#  ['Hasta', 'las', '16h15', 'no', 'nos', 'adjudicaron', 'la', 'mesa', '.'],
#  ['Situación', 'excelente', '.'],
#  ['Estupendo',
#   'el',
#   'arroz',
#   'caldoso',
#   'con',
#   'bogavante',
#   'y',
#   'muy',
#   'buen',
#   'trato',
#   '.'],
#  ['Conjuga',
#   'perfectamente',
#   'calidad',
#   ',',
#   'servicio',
#   'y',
#   'ambiente',
#   '.'],
#  ['<+>', 'personal', 'amable', '.'],
#  ['Una',
#   'pena',
#   'para',
#   'las',
#   'instalaciones',
#   'tan',
#   'excelentes',
#   'que',
#   'hay',
#   '.'],
#  ['Incluso',
#   'no',
#   'entendemos',
#   'porque',
#   'hicimos',
#   'la',
#   'reserva',
#   'porque',
#   'la',
#   'cola',
#   'la',
#   'sufrimos',
#   'igual',
#   '.'],
#  ['Es',
#   'decir',
#   ',',
#   'un',
#   'restaurante',
#   ',',
#   'cuando',
#   'estás',
#   'satisfecho',
#   ',',
#   'tienes',
#   'ganas',
#   'de',
#   'volver',
#   '.'],
#  ['Entre',
#   'otras',
#   'cosas',
#   'tengo',
#   'una',
#   'obsesión',
#   'con',
#   'la',
#   'prisa',
#   'que',
#   'tienen',
#   'algunos',
#   'en',
#   'retirar',
#   'los',
#   'platos',
#   'de',
#   'mesa',
#   'mientras',
#   'está',
#   'comiendo',
#   '.'],
#  ['Las',
#   'croquetas',
#   'literalmente',
#   'nos',
#   'las',
#   'tiró',
#   'en',
#   'la',
#   'mesa',
#   'sin',
#   'decir',
#   'ni',
#   'mu',
#   'la',
#   'camarera',
#   ',',
#   'porque',
#   'por',
#   'la',
#   'puerta',
#   'estaba',
#   'entrando',
#   'un',
#   'amigo',
#   'suyo',
#   'con',
#   'el',
#   'cual',
#   'se',
#   'sentó',
#   'a',
#   'conversar',
#   '.'],
#  ['Solo',
#   'con',
#   'el',
#   'primer',
#   'plato',
#   ',',
#   'tardaron',
#   'media',
#   'hora',
#   'en',
#   'servirlo',
#   'y',
#   'otra',
#   'media',
#   'hora',
#   'en',
#   'servir',
#   'los',
#   'segundos',
#   '...'],
#  ['Arróz', 'muy', 'bueno', 'y', 'buena', 'cantidad', '.'],
#  ['El', 'ambiente', 'muy', 'acogedor', '.'],
#  ['Es', 'altamente', 'recomendable', '.'],
#  ['Estuve',
#   'el',
#   'Sábado',
#   'pasado',
#   'y',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'me',
#   'gustó',
#   'mucho.Moderno',
#   ',',
#   'diferente',
#   ',',
#   'buen',
#   'servicio',
#   ',',
#   'carta',
#   'divertida',
#   'y',
#   'original',
#   '.'],
#  ['Buena', 'comida', ',', 'buen', 'servicio', 'y', 'sitio', 'precioso', '.'],
#  ['JAJAJAJA', ',', 'me', 'río', 'yo', 'de', 'los', 'tenedores', '.'],
#  ['La',
#   'verdad',
#   'es',
#   'que',
#   'puede',
#   'resultar',
#   'algo',
#   'car',
#   'pero',
#   'sales',
#   'con',
#   'la',
#   'sensación',
#   'de',
#   'haber',
#   'comido',
#   'bien',
#   'y',
#   'bastante',
#   '.'],
#  ['Hoy', 'hemos', 'comido', 'en', 'el', 'Barceloneta', '.'],
#  ['Como',
#   'siempre',
#   ',',
#   'servicio',
#   'muy',
#   'correcto',
#   ',',
#   'rápido',
#   'y',
#   'excelente',
#   'comida',
#   '.'],
#  ['La', 'comida', 'y', 'el', 'servicio', 'fueron', 'correctos', '.'],
#  ['Otra', 'cosa', 'sería', 'censura', 'y', 'coacción', '.'],
#  ['Si',
#   'no',
#   'te',
#   'gusta',
#   'tienes',
#   'los',
#   'WOK',
#   'que',
#   'es',
#   'un',
#   'self-service',
#   'hasta',
#   'que',
#   'no',
#   'puedas',
#   'más',
#   '…',
#   'Por',
#   'terminar',
#   ',',
#   'le',
#   'diré',
#   'que',
#   'a',
#   'este',
#   'restaurante',
#   'le',
#   'faltan',
#   'cosas',
#   '.'],
#  ['[',
#   '…',
#   ']',
#   'Restaurante',
#   'Bal',
#   'd',
#   '’',
#   'Onsera',
#   'de',
#   'Zaragoza',
#   ',',
#   'mantiene',
#   'su',
#   'estrella',
#   'Michelín',
#   'durante',
#   'el',
#   '2010',
#   '.',
#   '[',
#   '…',
#   ']'],
#  ['Hay',
#   'un',
#   'listado',
#   'de',
#   'sugerencias',
#   'plastificado',
#   'y',
#   'sin',
#   'precio',
#   ',',
#   'incluido',
#   'en',
#   'la',
#   'carta',
#   'y',
#   'tan',
#   'largo',
#   'como',
#   'la',
#   'carta',
#   '.'],
#  ['Sólo',
#   'pedimos',
#   'dos',
#   'postres',
#   'y',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'fueron',
#   'lo',
#   'más',
#   'flojo',
#   'de',
#   'la',
#   'cena',
#   ':'],
#  ['No',
#   'volveremos',
#   ',',
#   'nos',
#   'quedamos',
#   'con',
#   '“',
#   'La',
#   'Casa',
#   'de',
#   'Mar',
#   '”',
#   '.'],
#  ['Todo',
#   'fue',
#   'tal',
#   'y',
#   'como',
#   'esperabamos',
#   'y',
#   'nos',
#   'habian',
#   'comentado',
#   ',',
#   'buen',
#   'servicio',
#   ',',
#   'buen',
#   'ambiente',
#   'y',
#   'muy',
#   'buena',
#   'comida',
#   ',',
#   'en',
#   'un',
#   'ambiente',
#   'agradable',
#   ',',
#   'sin',
#   'duda',
#   'alguna',
#   'un',
#   'restaurant',
#   'donde',
#   'ir',
#   'cuando',
#   'se',
#   'desea',
#   'que',
#   'todos',
#   'queden',
#   'contentos',
#   '.'],
#  ['Sino',
#   'os',
#   'aseguro',
#   'que',
#   'cuando',
#   'un',
#   'postre',
#   'me',
#   'gusta',
#   'lo',
#   'recuerdo',
#   'muy',
#   'bien',
#   '.'],
#  ['Falta', 'algun', 'menu', 'de', 'pescado', '.'],
#  ['El',
#   'tomate',
#   'en',
#   'texturas',
#   'estaba',
#   'muy',
#   'sabroso',
#   ',',
#   'aunque',
#   'la',
#   'espuma',
#   'resultaba',
#   'un',
#   'tanto',
#   'dura',
#   '.'],
#  ['Lugar', 'muy', 'agradable'],
#  ['Es', 'una', 'pena', ',', 'era', 'de', 'lo', 'mejorcito', 'de', 'Barcelona'],
#  ['El',
#   'resto',
#   ',',
#   'pasable',
#   'y',
#   'sin',
#   'mas',
#   'pretensiones',
#   'pero',
#   'no',
#   'valía',
#   'el',
#   'precio',
#   'que',
#   'nos',
#   'cobraron',
#   '.'],
#  ['Tomamos',
#   'el',
#   'menú',
#   'calçotada',
#   'y',
#   'estuvo',
#   'muy',
#   'correcto',
#   'con',
#   'posibilidad',
#   'de',
#   'repetir',
#   'calçots',
#   'y',
#   'la',
#   'bebida',
#   'incluida',
#   'sin',
#   'límite',
#   '.'],
#  ['La', 'comida', 'deliciosa', 'y', 'el', 'servicio', 'muy', 'bueno', '.'],
#  ['Gema'],
#  ['<+>', 'Nunca', 'falla', '.'],
#  ['<->',
#   'Ya',
#   'hace',
#   'tiempo',
#   'que',
#   'no',
#   'encuentro',
#   'nada',
#   'negativo',
#   'en',
#   'este',
#   'restaurante',
#   '.'],
#  ['mejorables',
#   'las',
#   'costillas',
#   ',',
#   'ya',
#   'que',
#   'se',
#   'anuncia',
#   'costillas',
#   'y',
#   'se',
#   'incluyen',
#   'chuletas',
#   '.'],
#  ['Por',
#   'último',
#   ',',
#   'es',
#   'espectáculo',
#   'de',
#   'Drag',
#   'Queens',
#   ',',
#   'pues',
#   'bueno',
#   ',',
#   'estaba',
#   'programado',
#   'para',
#   'las',
#   '23:30',
#   'y',
#   'salieron',
#   'a',
#   'la',
#   '1',
#   ',',
#   'con',
#   'lo',
#   'que',
#   'sinceramente',
#   'ya',
#   'no',
#   'teníamos',
#   'mucho',
#   'humor',
#   'como',
#   'para',
#   'verlo',
#   'con',
#   'agrado',
#   '.'],
#  ['Pedro',
#   ':',
#   'Me',
#   'temo',
#   'que',
#   'no',
#   'has',
#   'probado',
#   'los',
#   'cavas',
#   'Aragones',
#   'adecuados',
#   'como',
#   'el',
#   'Cava',
#   'Monasterio',
#   'de',
#   'Veruela',
#   'o',
#   'el',
#   'Reinante',
#   ',',
#   'o',
#   'el',
#   'Real',
#   'de',
#   'Aragón',
#   ',',
#   '…',
#   'cualquier',
#   'de',
#   'estos',
#   'relación',
#   'calidad',
#   'precio',
#   'está',
#   'por',
#   'encima',
#   'de',
#   'los',
#   'Catalanes',
#   '.'],
#  ['En',
#   'cuanto',
#   'a',
#   'la',
#   'comida',
#   ',',
#   'bien',
#   'pero',
#   'nada',
#   'exclusivo',
#   'ni',
#   'sorprendente',
#   '.'],
#  ['Bonito', 'restaurante', ',', 'buen', 'ambiente', 'y', 'servicio', '.'],
#  ['Servicio', 'atento', 'al', 'cliente', '.'],
#  ['PD',
#   ':',
#   'No',
#   'tiene',
#   'nada',
#   'que',
#   'ver',
#   'con',
#   'la',
#   'película',
#   'de',
#   'Darín',
#   ',',
#   'solo',
#   'que',
#   'les',
#   'gustó',
#   'el',
#   'nombre',
#   '.'],
#  ['Una', 'pena'],
#  ['Totalmente',
#   'recomendable',
#   'para',
#   'cualquier',
#   'evento',
#   ':',
#   'familia',
#   ',',
#   'amigos',
#   'y',
#   'pareja'],
#  ['De',
#   'hecho',
#   'tuve',
#   'que',
#   'enseñar',
#   'la',
#   'confirmación',
#   'de',
#   'reserva',
#   'que',
#   'tenía',
#   'en',
#   'el',
#   'móvil',
#   '.'],
#  ['Fantástica', 'elección', '.'],
#  ['¿', 'Minimalista', '?'],
#  ['Me',
#   'encanta',
#   'llevar',
#   'a',
#   'la',
#   'gente',
#   'a',
#   'mi',
#   'tierra',
#   'y',
#   'que',
#   'vuelvan',
#   'encantados',
#   'del',
#   'trato',
#   'y',
#   'de',
#   'la',
#   'gente',
#   '.'],
#  ['Nos',
#   'dijo',
#   'que',
#   'si',
#   'queríamos',
#   'más',
#   'que',
#   'pidiéramos',
#   ',',
#   'gracias',
#   'de',
#   'nuevo',
#   '.'],
#  ['Casi', 'como', 'en', 'Argentina', '.'],
#  ['Es', 'eso', '?'],
#  ['peros',
#   ':',
#   'decoracion',
#   'y',
#   'ambiente',
#   'casi',
#   'retro',
#   ',',
#   'cobrar',
#   'por',
#   'pan',
#   'que',
#   'no',
#   'pedi',
#   'y',
#   'servicio',
#   '2,20',
#   '€',
#   'por',
#   'persona',
#   ',',
#   'pan',
#   'de',
#   'coca',
#   'con',
#   'tomate',
#   '3,20',
#   '€',
#   'excesivo',
#   ',',
#   'los',
#   'cafes',
#   'a',
#   '2',
#   '€',
#   ',',
#   'todo',
#   'mas',
#   'impuestos',
#   ',',
#   'servicio',
#   'urinario',
#   'hombres',
#   'con',
#   'grafitis',
#   ',',
#   'no',
#   'repetire',
#   '.'],
#  ['Servicio', 'atento', '.'],
#  ['Son',
#   'muchos',
#   ',',
#   'muchísimos',
#   ',',
#   'los',
#   'propietarios',
#   'de',
#   'restaurantes',
#   'que',
#   'me',
#   'han',
#   'confesado',
#   'que',
#   'no',
#   'aparecen',
#   'en',
#   'medios',
#   'especializados',
#   'si',
#   'no',
#   'compran',
#   'publicidad',
#   ',',
#   'si',
#   'no',
#   'invitan',
#   'a',
#   'los',
#   'listillos',
#   ',',
#   'etc',
#   '…',
#   'algunos',
#   'se',
#   'doblegan',
#   ',',
#   'que',
#   'remedio',
#   ',',
#   'es',
#   'el',
#   'pan',
#   'de',
#   'sus',
#   'hijos',
#   ',',
#   'otros',
#   'sin',
#   'embargo',
#   'estóicamente',
#   'aguantan',
#   'en',
#   'su',
#   'puesto',
#   'y',
#   'que',
#   'menos',
#   'que',
#   'los',
#   'humildes',
#   'clientes',
#   ',',
#   'como',
#   'el',
#   'que',
#   'escribe',
#   ',',
#   'digamos',
#   'públicamente',
#   'que',
#   'ellos',
#   'también',
#   'tienen',
#   'buenas',
#   'mesas',
#   '.'],
#  ['Excelente', 'comida', '.'],
#  ['Anonadado',
#   'me',
#   'hallo',
#   ',',
#   '¿',
#   'y',
#   'cómo',
#   'has',
#   'llegado',
#   'a',
#   'tales',
#   'conclusiones',
#   '?',
#   ',',
#   'porque',
#   'no',
#   'utilizo',
#   'las',
#   'mayúsculas',
#   'en',
#   'un',
#   'gentilicio',
#   '?',
#   '.'],
#  ['El',
#   'servicio',
#   'muy',
#   'justo',
#   ',',
#   'el',
#   'ambiente',
#   'un',
#   'poco',
#   'decadente',
#   ',',
#   'y',
#   'tanto',
#   'la',
#   'paella',
#   ',',
#   'como',
#   'la',
#   'fideuá',
#   ',',
#   'sin',
#   'sabor',
#   ',',
#   'prefabricadas',
#   'y',
#   'casi',
#   'incomibles',
#   '.'],
#  ['Todo',
#   'correcto',
#   'para',
#   'el',
#   'nivel',
#   'de',
#   'gente',
#   'que',
#   'había',
#   '.'],
#  ['En',
#   'cuanto',
#   'a',
#   'la',
#   'cuestión',
#   'principal',
#   ',',
#   'las',
#   'críticas',
#   'en',
#   'sí',
#   'mismas',
#   ',',
#   'me',
#   'parecen',
#   'valientes',
#   ',',
#   'y',
#   'además',
#   ',',
#   'en',
#   'la',
#   'mayor',
#   'parte',
#   'de',
#   'las',
#   'ocasiones',
#   ',',
#   'coinciden',
#   'con',
#   'mi',
#   'opinión',
#   ',',
#   'de',
#   'lo',
#   'que',
#   'deduzco',
#   'que',
#   'además',
#   'de',
#   'tener',
#   'los',
#   'mismos',
#   'gustos',
#   'y',
#   'criterios',
#   'es',
#   'Ud',
#   '.'],
#  ['Pues',
#   'bien',
#   ',',
#   'para',
#   'empezar',
#   ',',
#   'llegamos',
#   'al',
#   'restaurante',
#   ',',
#   'y',
#   'éramos',
#   'los',
#   'primeros',
#   ',',
#   'todo',
#   'el',
#   'comedor',
#   'para',
#   'nosotros',
#   'solos',
#   '!'],
#  ['Si',
#   'sólo',
#   'te',
#   'paraste',
#   'a',
#   'valorar',
#   'el',
#   'coste',
#   'del',
#   'stock',
#   ',',
#   'mal',
#   'empezamos',
#   '.'],
#  ['Respecto',
#   'al',
#   'precio',
#   ',',
#   'si',
#   'lo',
#   'comparas',
#   'con',
#   'la',
#   'calidad',
#   'y',
#   'el',
#   'sevicio',
#   'y',
#   'la',
#   'exclusividad',
#   'esta',
#   'perfecto',
#   ',',
#   'mas',
#   'si',
#   'lo',
#   'comparas',
#   'con',
#   'otros',
#   'restaurates',
#   'de',
#   'esta',
#   'clase',
#   'en',
#   'el',
#   'resto',
#   'de',
#   'españa',
#   '.'],
#  ['Enhorabuena',
#   'teneis',
#   'un',
#   'estupendo',
#   'restaurante',
#   '.',
#   'Hemos',
#   'cenado',
#   'de',
#   'maravilla',
#   '.'],
#  ['Excepto', 'el', 'ambientador', 'utilizado', 'en', 'el', 'local'],
#  ['Hay',
#   'una',
#   'puntualización',
#   'importante',
#   'que',
#   'no',
#   'me',
#   'ha',
#   'parecido',
#   'leer',
#   'en',
#   'la',
#   'crítica',
#   ':',
#   'el',
#   'menú',
#   'cerrado',
#   'de',
#   '30',
#   '€',
#   'es',
#   'para',
#   'grupos',
#   'de',
#   'un',
#   'mínimo',
#   'de',
#   '8',
#   'personas',
#   '.'],
#  ['Relacion', 'calidad', 'precii', 'muy', 'buena', '.'],
#  ['Todo', 'muy', 'bien', '.'],
#  ['Servicio', 'atento', 'y', 'rápido', '.'],
#  ['Un', '10', 'en', 'comida', 'mediterranea', '!'],
#  ['Buen', 'servicio', 'y', 'buen', 'ambiente', '.'],
#  ['La',
#   'cena',
#   'normal',
#   ',',
#   'unos',
#   'productos',
#   'mejor',
#   'que',
#   'otros',
#   '.'],
#  ['Se',
#   'acerca',
#   'más',
#   'a',
#   'los',
#   '45',
#   'que',
#   'a',
#   'los',
#   'treinta',
#   'euros',
#   '.'],
#  ['No',
#   'habiamos',
#   'terminado',
#   'todavía',
#   'los',
#   'entrantes',
#   'y',
#   'ya',
#   'venian',
#   'a',
#   'retirar',
#   'los',
#   'platos',
#   'para',
#   'poner',
#   'el',
#   'segundo',
#   '.'],
#  ['Sin',
#   'duda',
#   ',',
#   'lo',
#   'peor',
#   'del',
#   'restaurante',
#   'es',
#   'la',
#   'decoración',
#   ',',
#   'extrañamente',
#   'alabada',
#   'por',
#   'algunos',
#   '.'],
#  ['Creo', 'que', 'el', 'título', 'lo', 'indica', 'todo', '.'],
#  ['tremenda', 'amabilidad', ',', 'es', 'un', 'gustazo', '!'],
#  ['solo',
#   'dijo',
#   'que',
#   'es',
#   'un',
#   'sitio',
#   'alucinate',
#   ',',
#   'comida',
#   'sevicio',
#   'y',
#   'decoracion',
#   ',',
#   'lo',
#   'que',
#   'mas',
#   'me',
#   'gusto',
#   'fue',
#   'la',
#   'comida',
#   'ya',
#   'que',
#   'es',
#   'de',
#   'muy',
#   'buena',
#   'calidad',
#   ',',
#   'espero',
#   'que',
#   'en',
#   'un',
#   'futuro',
#   'se',
#   'igual',
#   'y',
#   'que',
#   'no',
#   'cambie',
#   '.'],
#  ['Un', 'valor', 'seguro', '.'],
#  ['Buen',
#   'servicio',
#   ',',
#   'buena',
#   'comida',
#   'y',
#   'a',
#   'precio',
#   'medio',
#   '.'],
#  ['Gazpacho', 'de', 'Zaragoza', '.'],
#  ['[',
#   '…',
#   ']',
#   'sábado',
#   'estuve',
#   'cenando',
#   'en',
#   'el',
#   'nuevo',
#   'restaurante',
#   'Q-Art',
#   '(',
#   'hacer',
#   'click',
#   'para',
#   'ver',
#   'la',
#   'crítica',
#   ')',
#   ',',
#   'desastroso',
#   ',',
#   'no',
#   'volveré',
#   '.'],
#  ['Y',
#   'para',
#   'finalizar',
#   ',',
#   'cuando',
#   'pedimos',
#   'el',
#   'café',
#   ',',
#   'se',
#   'nos',
#   'advirtió',
#   'que',
#   'fuéramos',
#   'rápidos',
#   '.',
#   'En',
#   'fin',
#   ',',
#   'muy',
#   'mal',
#   'servicio',
#   'y',
#   'mala',
#   'comida',
#   '.'],
#  ['Todo', 'muy', 'bueno', ',', 'repetiria', 'y', 'recomendaria', '.'],
#  ['Ahí',
#   'se',
#   'quedaron',
#   'la',
#   'mayoría',
#   ',',
#   'eran',
#   'bastante',
#   'normalillos',
#   'y',
#   'además',
#   'ya',
#   'no',
#   'podíamos',
#   'más',
#   '.',
#   'En',
#   'resumen',
#   '280',
#   '€',
#   'para',
#   '4',
#   'personas',
#   'incluyendo',
#   'dos',
#   'botellas',
#   'de',
#   'Enate',
#   'Merlot-merlot',
#   '(',
#   'que',
#   'contribuyeron',
#   'en',
#   '60',
#   '€',
#   'a',
#   'la',
#   'cuenta',
#   ')',
#   'Creo',
#   'que',
#   'una',
#   'cuenta',
#   'nada',
#   'desproporcionada',
#   'con',
#   'la',
#   'calidad',
#   'y',
#   'cantidad',
#   'de',
#   'la',
#   'comida',
#   'y',
#   'de',
#   'los',
#   'detalles',
#   'que',
#   'nos',
#   'ofrecieron',
#   '.'],
#  ['Excelente', 'materia', 'prima', 'y', 'muy', 'buena', 'elaboración', '.'],
#  ['No', 'cogimos', 'menú', ',', 'cogimos', 'platos', 'sueltos', '.'],
#  ['Ya', 'hemos', 'repetido', 'y', 'volveremos', 'a', 'hacerlo', '.'],
#  ['De',
#   'la',
#   'comida',
#   'no',
#   'tengo',
#   'nada',
#   'que',
#   'decir',
#   ',',
#   'pero',
#   'las',
#   'mesas',
#   'se',
#   'tocan',
#   ',',
#   'el',
#   'servicio',
#   'no',
#   'es',
#   'amable',
#   ',',
#   'en',
#   'definitiva',
#   'muy',
#   'caro',
#   'para',
#   'lo',
#   'que',
#   'es',
#   'calida',
#   'precio',
#   'totalmente',
#   'desequilibrada',
#   '.'],
#  ['Coincido', 'con', 'los', 'Datos', 'de', 'la', 'ficha', '.'],
#  ['La', 'Tarta', 'de', 'manzana', ',', 'hummmm', '.'],
#  ['Aunque',
#   'lo',
#   'que',
#   'realmente',
#   'me',
#   'ha',
#   'impresionado',
#   'es',
#   'la',
#   'calidad',
#   'de',
#   'los',
#   'platos',
#   '.'],
#  ['Por',
#   'lo',
#   'demás',
#   'el',
#   'lugar',
#   ',',
#   'situación',
#   ',',
#   'elaboración',
#   'y',
#   'la',
#   'relación',
#   'calidad',
#   'precio',
#   'fue',
#   'excelente',
#   'incluso',
#   'ideal',
#   'también',
#   'para',
#   'niños',
#   '.'],
#  ['Mejor', 'carne', 'de', 'BCN', '.'],
#  ['El', 'servicio', 'excelente', '.'],
#  ['Perfecta',
#   'relación',
#   'calidad-precio',
#   ',',
#   'servicio',
#   'muy',
#   'atento',
#   'y',
#   'comida',
#   'exquisita',
#   '.'],
#  ['Se',
#   'lo',
#   'recomiendo',
#   'a',
#   'todos',
#   'los',
#   'que',
#   'esten',
#   'buscando',
#   'un',
#   'lugar',
#   'donde',
#   'celebrar',
#   'una',
#   'comida',
#   'entre',
#   'amigos',
#   'o',
#   'de',
#   'trabajo',
#   'y',
#   'tambien',
#   'a',
#   'parejas',
#   'ya',
#   'que',
#   'se',
#   'trata',
#   'de',
#   'un',
#   'lugar',
#   'tranquilo',
#   'y',
#   'agradable',
#   'con',
#   'unos',
#   'platos',
#   'sencillos',
#   'y',
#   'con',
#   'mucha',
#   'calidad',
#   '.'],
#  ['Amo', 'el', 'pescado', 'en', 'Salamanca', '!'],
#  ['-', 'Pichón', '.'],
#  ['Camareros',
#   'con',
#   'poca',
#   'experiencia',
#   'y',
#   'poco',
#   'preparados',
#   'para',
#   'el',
#   'precio',
#   'pagado',
#   '.'],
#  ['Siempre',
#   'vamos',
#   'cuando',
#   'no',
#   'sabemos',
#   'adonde',
#   'ir',
#   'para',
#   'cenar',
#   ',',
#   'la',
#   'comida',
#   'esta',
#   'bien',
#   'y',
#   'el',
#   'precio',
#   'en',
#   'comparacion',
#   'vale',
#   'la',
#   'pena',
#   '.'],
#  ['Gracias', '.'],
#  ['Elegimos',
#   'un',
#   'menú',
#   'cerrado',
#   'y',
#   'cuando',
#   'iban',
#   'a',
#   'empezar',
#   'a',
#   'servir',
#   ',',
#   'nos',
#   'avisaron',
#   'de',
#   'que',
#   'cambiaban',
#   'el',
#   'arroz',
#   'negro',
#   'caldoso',
#   'con',
#   'sepia',
#   'por',
#   'un',
#   'arroz',
#   'caldoso',
#   'con',
#   'chorizo',
#   '(',
#   '¡',
#   '!',
#   ')',
#   '.'],
#  ['Calidad', 'precio', 'Exelente', '.'],
#  ['Excelente', ',', 'como', 'siempre', '.'],
#  ['Cenar',
#   'en',
#   'la',
#   'terraza',
#   ':',
#   'fantastico',
#   ',',
#   'el',
#   'servicio',
#   ':',
#   'excelente',
#   ',',
#   'la',
#   'comida',
#   ':',
#   'fabulosa',
#   ',',
#   'el',
#   'precio',
#   ':',
#   'bueno',
#   ',',
#   'pelín',
#   'caro',
#   ',',
#   'pero',
#   'vale',
#   'la',
#   'pena',
#   '.'],
#  ['Para', 'repetir'],
#  ['Un',
#   'último',
#   'comentario',
#   'a',
#   'favor',
#   'del',
#   'cocinero',
#   'es',
#   'que',
#   'el',
#   'pasado',
#   'año',
#   'estuvo',
#   'invitado',
#   'en',
#   'la',
#   'pasada',
#   'Expo',
#   'en',
#   'China',
#   '(',
#   'salió',
#   'en',
#   'prensa',
#   ')',
#   ',',
#   'y',
#   'los',
#   'platos',
#   'que',
#   'presentó',
#   'en',
#   'la',
#   'semana',
#   'española',
#   'eran',
#   'típicos',
#   'aragoneses',
#   '(',
#   'borraja',
#   ',',
#   'ternasco',
#   '…',
#   'y',
#   'todo',
#   'con',
#   'vinos',
#   'aragoneses',
#   ')',
#   '.',
#   'Con',
#   'esto',
#   'lo',
#   'único',
#   'que',
#   'quiero',
#   'indicar',
#   'es',
#   'mi',
#   'sorpresa',
#   'por',
#   'la',
#   'propaganda',
#   'de',
#   'la',
#   'comida',
#   'aragonesa',
#   ',',
#   'cosa',
#   'que',
#   'me',
#   'alegro',
#   'que',
#   'alguien',
#   'la',
#   'defienda',
#   '(',
#   'y',
#   'lo',
#   'dice',
#   'un',
#   'aragonés',
#   'español',
#   ')',
#   '.'],
#  ['Supongo',
#   'que',
#   'cortaron',
#   'la',
#   'piña',
#   'con',
#   'el',
#   'mismo',
#   'cuchillo',
#   'con',
#   'que',
#   'cortaron',
#   'el',
#   'ajo',
#   '.'],
#  ['La', 'comida', 'fatal', 'y', 'para', 'colmo', 'el', 'precio', '.'],
#  ['Francamente', ',', 'no', 'me', 'gustó', 'el', 'trato', '.'],
#  ['Vamos', 'como', 'en', 'casa', 'para', 'salir', 'del', 'paso', '.'],
#  ['No', 'obstante', 'buena', 'relación', 'calidad', 'precio', '.'],
#  ['pero',
#   'la',
#   'experiencia',
#   'me',
#   'sirvió',
#   'para',
#   'conocer',
#   'restaurantes',
#   '.'],
#  ['En',
#   'cuanto',
#   'a',
#   'la',
#   'carta',
#   ',',
#   'el',
#   'tartar',
#   'de',
#   'lubina',
#   ',',
#   'supremo',
#   'así',
#   'como',
#   'sus',
#   'postres',
#   '.'],
#  ['La', 'relación', 'calidad', 'precio', 'es', 'muy', 'buena', '.'],
#  ['el',
#   'servicio',
#   'muy',
#   'correcto',
#   ',',
#   'la',
#   'comida',
#   'muy',
#   'buena',
#   'exceoti',
#   'el',
#   'tiramisú',
#   ',',
#   'que',
#   'para',
#   'mi',
#   'gusto',
#   ',',
#   'era',
#   'amargo',
#   '.'],
#  ['Buena',
#   'localización',
#   'en',
#   'el',
#   'centro',
#   'de',
#   'la',
#   'Barcelona',
#   'delant',
#   'de',
#   'mar',
#   '.'],
#  ['La',
#   'calidad',
#   'de',
#   'las',
#   'carnes',
#   'es',
#   'insuperable',
#   'y',
#   'quiero',
#   'destacar',
#   'el',
#   'excelente',
#   'servicio',
#   'recibido',
#   '.'],
#  ['Servicio', 'impecable', 'y', 'se', 'come', 'de', 'maravilla', '!'],
#  ['comimos',
#   'unos',
#   'generosos',
#   'platos',
#   'de',
#   'arroz',
#   'y',
#   'unos',
#   'entrantes',
#   'a',
#   'base',
#   'de',
#   'berberechos',
#   'al',
#   'vapor',
#   ',',
#   'gamba',
#   'de',
#   'Huelva',
#   'y',
#   'variado',
#   'de',
#   'friduria',
#   'andaluza',
#   'bastante',
#   'buenos',
#   '.'],
#  ['Entrada',
#   'algo',
#   'desordenada',
#   ',',
#   'con',
#   'papel',
#   'en',
#   'suelo',
#   '.',
#   'vibración',
#   'del',
#   'metro',
#   'y',
#   'ruido',
#   'de',
#   'sala',
#   'molesto',
#   '.'],
#  ['Sábado',
#   'por',
#   'la',
#   'noche',
#   ',',
#   'reservo',
#   'para',
#   '4',
#   'personas',
#   'en',
#   'el',
#   'colette',
#   ',',
#   'y',
#   'al',
#   'llegar',
#   'no',
#   'sólo',
#   'no',
#   'tenemos',
#   'reserva',
#   'sino',
#   'que',
#   'el',
#   'colette',
#   ',',
#   'supuestamente',
#   'de',
#   'más',
#   'calidad',
#   'que',
#   'el',
#   'Quartz',
#   ',',
#   'ya',
#   'no',
#   'existe',
#   'como',
#   'tal',
#   ',',
#   'nos',
#   'dicen',
#   'que',
#   'se',
#   'han',
#   'fusionado',
#   ',',
#   'son',
#   'el',
#   'mismo',
#   'restaurante',
#   'y',
#   'nos',
#   'buscan',
#   'una',
#   'mesa',
#   'en',
#   'este',
#   'ultimo',
#   '.'],
#  ['Enhorabuena', '!', '!', ',', 'ahora', 'sí', 'lo', 'has', 'entendido', '.'],
#  ['Ya',
#   'habiamos',
#   'estado',
#   'en',
#   'el',
#   'anterior',
#   'en',
#   'la',
#   'calle',
#   'muntaner',
#   '.'],
#  ['Un', 'servicio', 'y', 'una', 'comida', 'más', 'que', 'correcto', '.'],
#  ['La', 'carne', 'bién', 'también', '.'],
#  ['-',
#   'LA',
#   'CARTA',
#   'DE',
#   'VINOS',
#   ':',
#   'Desgraciadamente',
#   'no',
#   'me',
#   'considero',
#   'un',
#   'experto',
#   'pero',
#   'dado',
#   'las',
#   'dimensiones',
#   'tan',
#   'reducidas',
#   'del',
#   'local',
#   ',',
#   'me',
#   'parece',
#   'una',
#   'carta',
#   'muy',
#   'acertada',
#   '.'],
#  ['La',
#   'educacion',
#   'del',
#   'director',
#   'fernando',
#   'nieto',
#   ',',
#   'deja',
#   'mucho',
#   'que',
#   'desear',
#   ',',
#   'no',
#   'es',
#   'logico',
#   'que',
#   'mientras',
#   'uno',
#   'disfruta',
#   'de',
#   'su',
#   'comida',
#   'le',
#   'metan',
#   'prisa',
#   'por',
#   'comer',
#   ',',
#   'y',
#   'le',
#   'meta',
#   'bronca',
#   'a',
#   'los',
#   'camareros',
#   'en',
#   'la',
#   'sala',
#   ',',
#   'donde',
#   'todos',
#   'los',
#   'clientes',
#   'escuchan',
#   'sus',
#   'gritos',
#   '.'],
#  ['Comida', 'y', 'vistas', 'excepcionale', '.'],
#  ['veo',
#   'que',
#   'las',
#   'opiniones',
#   'son',
#   'mayoritariamente',
#   'favorables',
#   ',',
#   'en',
#   'cambio',
#   'a',
#   'mi',
#   'no',
#   'me',
#   'gusto',
#   '.'],
#  ['Muy', 'recomendable', '.'],
#  ['Me',
#   'parece',
#   'un',
#   'lugar',
#   'estupendo',
#   ',',
#   'la',
#   'comida',
#   'está',
#   'buenisima',
#   'y',
#   'el',
#   'servicio',
#   'estupendo',
#   ',',
#   'dignos',
#   'de',
#   'admirar',
#   '.'],
#  ['Luces',
#   'y',
#   'sombras',
#   'en',
#   'mi',
#   'esperada',
#   'primera',
#   'visita',
#   'al',
#   'Meccano',
#   '.'],
#  ['Y', 'la', 'verdad', 'que', 'lo', 'pasamos', 'estupendo', '.'],
#  ['Si',
#   'tienes',
#   'un',
#   'negocio',
#   'de',
#   'hostelería',
#   'tienes',
#   'que',
#   'actuar',
#   'en',
#   'consecuencia',
#   '.'],
#  ['Repetiremos', '.'],
#  ['Íbamos',
#   'ya',
#   'con',
#   'la',
#   'idea',
#   'de',
#   'pedir',
#   'el',
#   'menú',
#   'degustación',
#   'y',
#   'así',
#   'lo',
#   'hicimos',
#   '.'],
#  ['Caro',
#   'por',
#   'lo',
#   'que',
#   'dan',
#   'de',
#   'comer',
#   ',',
#   'mesas',
#   'muy',
#   'juntas',
#   'y',
#   'bastante',
#   'ruido',
#   '.'],
#  ['La',
#   'comida',
#   'y',
#   'el',
#   'servicio',
#   'muy',
#   'bien',
#   'y',
#   'el',
#   'precio',
#   'mejor',
#   'todavía',
#   '.'],
#  ['Las',
#   'ortiguillas',
#   'no',
#   'se',
#   'parecían',
#   'en',
#   'nada',
#   'al',
#   'recuerdo',
#   'que',
#   'yo',
#   'tenía',
#   'de',
#   'las',
#   'de',
#   'Cádiz',
#   ',',
#   'había',
#   'un',
#   'par',
#   'de',
#   'personas',
#   'fumando',
#   'en',
#   'zona',
#   'de',
#   'no',
#   'fumadores',
#   ',',
#   'pero',
#   'lo',
#   'peor',
#   'de',
#   'todo',
#   'fue',
#   'la',
#   'manera',
#   'de',
#   'atendernos',
#   'de',
#   'la',
#   '“',
#   'maitre',
#   '”',
#   ',',
#   'era',
#   'seria',
#   ',',
#   'seca',
#   ',',
#   'arisca',
#   'y',
#   'parecía',
#   'estar',
#   'dos',
#   'o',
#   'tres',
#   'escalones',
#   'por',
#   'debajo',
#   'del',
#   'lugar',
#   'en',
#   'el',
#   'que',
#   'trabajaba',
#   ',',
#   'estaba',
#   'poco',
#   'dispuesta',
#   'a',
#   'nuestra',
#   'atención',
#   'ya',
#   'que',
#   'se',
#   'le',
#   'veía',
#   'todo',
#   'el',
#   'rato',
#   'en',
#   'la',
#   'cocina',
#   'hablando',
#   'con',
#   'otra',
#   'de',
#   'sus',
#   'compañeras',
#   '.'],
#  ['Pero',
#   'también',
#   'creo',
#   'que',
#   'este',
#   'reconocimiento',
#   'debería',
#   'hacer',
#   'reflexionar',
#   'a',
#   'aquellas',
#   'voces',
#   'o',
#   'comentarios',
#   'críticos',
#   ',',
#   'que',
#   'también',
#   'se',
#   'pueden',
#   'equivocar.Zaragozana'],
#  ['Me',
#   'ha',
#   'causado',
#   'una',
#   'gratisima',
#   'impresión',
#   ',',
#   'tanto',
#   'en',
#   'la',
#   'calidad',
#   'de',
#   'sus',
#   'productos',
#   'como',
#   'en',
#   'el',
#   'exquisito',
#   'trato',
#   'de',
#   'su',
#   'personal',
#   '.'],
#  ['Excelente', '!'],
#  ['Elegimos',
#   'el',
#   'menú',
#   'B',
#   '(',
#   '25',
#   'euros',
#   'por',
#   'cabeza',
#   ')',
#   '.'],
#  ['Respecto',
#   'al',
#   'servicio',
#   'estoy',
#   'en',
#   'desacuerdo',
#   'con',
#   'la',
#   'critica',
#   'de',
#   'abajo',
#   ',',
#   'tanto',
#   'Silvestre',
#   '(',
#   'entrañable',
#   ')',
#   'como',
#   'todo',
#   'su',
#   'equipo',
#   'tratan',
#   'de',
#   'forma',
#   'excepcional',
#   'a',
#   'todos',
#   'sus',
#   'comensales',
#   ',',
#   'que',
#   'unido',
#   'a',
#   'la',
#   'belleza',
#   'de',
#   'todos',
#   'sus',
#   'salones',
#   'te',
#   'hace',
#   'sentir',
#   'en',
#   'un',
#   'sitio',
#   'especial',
#   '.'],
#  ['Ambiente', 'cálido', 'y', 'agradable', '.'],
#  ['Se', 'pasa', 'un', 'muy', 'buen', 'rato', 'en', 'este', 'restaurante', '.'],
#  ['Y',
#   'el',
#   'menú',
#   'para',
#   'niños',
#   'es',
#   'un',
#   'cuadra',
#   'cuentas',
#   ';',
#   'el',
#   'menú',
#   'sigue',
#   'la',
#   'lógica',
#   'de',
#   'lo',
#   'que',
#   'un',
#   'niño',
#   'puede',
#   'comer',
#   'sin',
#   'complicaciones',
#   'y',
#   'está',
#   'todo',
#   'bueno',
#   ',',
#   'pero',
#   'sigue',
#   'la',
#   'tónica',
#   'del',
#   'resto',
#   ':',
#   'caro.Queda',
#   'la',
#   'duda',
#   'de',
#   'cómo',
#   'será',
#   'comer',
#   'de',
#   'carta',
#   ',',
#   'pero',
#   'por',
#   'cuenta',
#   'propia',
#   ',',
#   'habiendo',
#   'tantas',
#   'opciones',
#   'disponibles',
#   ',',
#   'no',
#   'creo',
#   'que',
#   'vuelva',
#   'para',
#   'comprobarlo',
#   '.'],
#  ['Nos',
#   'trataron',
#   'muy',
#   'bien',
#   ',',
#   'trato',
#   'humano',
#   ',',
#   'nos',
#   'regalaron',
#   'doble',
#   'ronda',
#   'de',
#   'copas',
#   '.'],
#  ['Es', 'un', 'Restaurante', 'muy', 'recomendable', '.'],
#  ['Excelente',
#   'carta',
#   ',',
#   'carnes',
#   'exquisitas',
#   ',',
#   'especialidades',
#   'riquísimas',
#   ',',
#   'ambiente',
#   'íntimo',
#   'y',
#   'servicio',
#   'atento',
#   '.'],
#  ['Servicio', 'esmerado', '.'],
#  ['Éramos',
#   '9',
#   ',',
#   'y',
#   'sacaron',
#   '12',
#   'croquetas',
#   '…',
#   '¿',
#   'Cómo',
#   'nos',
#   'comemos',
#   '1',
#   'croqueta',
#   'y',
#   '1/3',
#   'cada',
#   'uno',
#   '?'],
#  ['se', 'esmeran', 'en', 'hacerlo', 'bien'],
#  ['Escriba', 'aquí', 'su', 'comentario', '…'],
#  ['Mi',
#   'acompañante',
#   'una',
#   'sopa',
#   'de',
#   'cebolla',
#   ',',
#   'que',
#   'de',
#   'textura',
#   'y',
#   'de',
#   'sabor',
#   'estaban',
#   'muy',
#   'buenas',
#   ',',
#   'pero',
#   'parecía',
#   'poca',
#   'cosa',
#   ',',
#   'porque',
#   'en',
#   'pocas',
#   'cucharadas',
#   'se',
#   'acaba',
#   'de',
#   'comer',
#   'enseguida',
#   '.'],
#  ['Despues',
#   'nos',
#   'pusieron',
#   '3',
#   'albondigas',
#   'de',
#   'pollo',
#   'de',
#   'corral',
#   'que',
#   'fue',
#   'sin',
#   'duda',
#   'el',
#   'peor',
#   'plato',
#   '.'],
#  ['Joer',
#   'como',
#   'para',
#   'ir',
#   ',',
#   'a',
#   'mi',
#   'no',
#   'se',
#   'me',
#   'rien',
#   'me',
#   'voy',
#   'sin',
#   'pagar',
#   'delante',
#   'de',
#   'ellos',
#   'y',
#   'punto',
#   ',',
#   'que',
#   'salgan',
#   'a',
#   'la',
#   'calle',
#   'a',
#   'buscarme',
#   '.'],
#  ['Primer',
#   'comida',
#   'de',
#   '“',
#   'negocio',
#   '”',
#   'y',
#   'mi',
#   'memoria',
#   'gustativa',
#   'recuerda',
#   'a',
#   'la',
#   'perfección',
#   'el',
#   'sabor',
#   'de',
#   'los',
#   'pescaditos',
#   'fritos',
#   ',',
#   'paella',
#   '..',
#   'El',
#   'trato',
#   'del',
#   'personal',
#   'es',
#   'notable',
#   ',',
#   'siempre',
#   'están',
#   'vigilando',
#   'que',
#   'no',
#   'falte',
#   'nada',
#   'en',
#   'la',
#   'mesa',
#   '.'],
#  ['Repito',
#   'cada',
#   'vez',
#   'que',
#   'puedo',
#   ',',
#   'con',
#   'la',
#   'familia',
#   'o',
#   'con',
#   'la',
#   'empresa',
#   '.'],
#  ['Ayer', 'estuvimos', 'cenando', 'en', 'Colette', '.'],
#  ['Rapidez', '.'],
#  ['por',
#   'eso',
#   'regresamos',
#   'cada',
#   'vez',
#   'que',
#   'podemos',
#   'por',
#   'que',
#   'vale',
#   'la',
#   'pena',
#   ',',
#   'y',
#   'si',
#   'que',
#   'es',
#   'recomendable',
#   'A',
#   '/',
#   't',
#   '.'],
#  ['La',
#   'comida',
#   'insuperable',
#   ',',
#   'fresca',
#   ',',
#   'tierna',
#   ',',
#   'la',
#   'presentación',
#   'muy',
#   'original',
#   'y',
#   'creativa',
#   '.'],
#  ['Pésimo', '.'],
#  ['Volveremos',
#   'sin',
#   'lugar',
#   'a',
#   'dudas',
#   ',',
#   'nos',
#   'quedan',
#   'por',
#   'probar',
#   'muchas',
#   'cosas',
#   '...',
#   'Enhorabuena',
#   'seguid',
#   'así',
#   '!'],
#  ['La',
#   'comida',
#   'bastante',
#   'bien',
#   '(',
#   'calidad',
#   'y',
#   'cantidad',
#   ')',
#   ',',
#   'aunque',
#   'tardó',
#   'en',
#   'ser',
#   'servida',
#   '(',
#   'es',
#   'cierto',
#   'que',
#   'estaba',
#   'lleno',
#   ',',
#   'el',
#   'local',
#   ',',
#   'pero',
#   '...',
#   'hay',
#   'que',
#   'preveerlo',
#   'teniendo',
#   'más',
#   'personal',
#   'o',
#   'cogiendo',
#   'menos',
#   'servicios',
#   ')',
#   '.'],
#  ['Sí',
#   'es',
#   'cierto',
#   'que',
#   'tardaron',
#   'muchísimo',
#   'en',
#   'atendernos',
#   'y',
#   'que',
#   'faltan',
#   'pequeños',
#   'detalles',
#   'como',
#   'una',
#   'carta',
#   'de',
#   'vinos',
#   '.'],
#  ['Realmente', '100', '%', 'recomendable'],
#  ['Al',
#   'final',
#   'pagamos',
#   ':',
#   '38',
#   'por',
#   'persona',
#   ',',
#   '10',
#   'euros',
#   'por',
#   'un',
#   'plato',
#   'de',
#   'tomate',
#   'de',
#   'la',
#   'huerta',
#   'que',
#   'cultiban',
#   'ellos',
#   '(',
#   'ofrecido',
#   'de',
#   'repente',
#   'teniendo',
#   'el',
#   'menú',
#   'cerrado',
#   'y',
#   'sin',
#   'avisar',
#   'del',
#   'precio',
#   ')',
#   ',',
#   '2',
#   'euros',
#   'por',
#   'café',
#   ',',
#   '5.5',
#   'por',
#   'pacharán',
#   '(',
#   'de',
#   'esto',
#   'no',
#   'digo',
#   'nada',
#   ',',
#   'si',
#   'lo',
#   'pides',
#   'lo',
#   'pagas',
#   ')',
#   'y',
#   '13',
#   'euros',
#   'por',
#   'una',
#   'botella',
#   'de',
#   'vino',
#   'teniendo',
#   'el',
#   'menú',
#   'cerrado',
#   '.'],
#  ['Obvio', '.'],
#  ['una', 'persona', 'cabal', 'y', 'honesta', '.'],
#  ['Un', 'sito', 'ideal', 'para', 'una', 'comida', 'de', 'negocios', '.'],
#  ['La',
#   'comida',
#   'siempre',
#   'ha',
#   'sido',
#   'muy',
#   'buena',
#   ',',
#   'creo',
#   'que',
#   'estas',
#   'personas',
#   'han',
#   'tenido',
#   'mala',
#   'suerte',
#   'porque',
#   'en',
#   'realidad',
#   'voy',
#   'dos',
#   'o',
#   '3',
#   'veces',
#   'al',
#   'año',
#   'y',
#   'siempre',
#   'slago',
#   'contenta',
#   '.'],
#  ['El',
#   'producto',
#   'de',
#   'primera',
#   ',',
#   'la',
#   'elaboración',
#   'excelente',
#   'y',
#   'el',
#   'servicio',
#   'impecable',
#   '.'],
#  ['Buena', 'cara', 'de', 'vinos', '.'],
#  ['-',
#   'Solomillo',
#   'con',
#   'foie',
#   'y',
#   'setas',
#   'de',
#   'temporada',
#   ':',
#   'gigantesca',
#   'ración',
#   'y',
#   'punto',
#   'exactamente',
#   'como',
#   'se',
#   'pidió',
#   ',',
#   'cosa',
#   'poco',
#   'común',
#   '.'],
#  ['Comida',
#   'buena',
#   ',',
#   'servicio',
#   'muy',
#   'bueno',
#   ',',
#   'atención',
#   'al',
#   'cliente',
#   'excelente',
#   '.'],
#  ['Y',
#   'si',
#   'bien',
#   'repito',
#   'que',
#   'la',
#   'comida',
#   'estaba',
#   'muy',
#   'correcta',
#   ',',
#   'incluso',
#   'por',
#   'encima',
#   'de',
#   'la',
#   'media',
#   'de',
#   'lo',
#   'que',
#   'se',
#   'come',
#   'en',
#   'muchos',
#   'sitios',
#   ',',
#   'lo',
#   'cierto',
#   'es',
#   'que',
#   'la',
#   'cantidad',
#   'de',
#   'las',
#   'raciones',
#   'era',
#   'justita',
#   '.'],
#  ['restaurante',
#   'de',
#   'lujo',
#   'autentico',
#   ',',
#   'con',
#   'un',
#   'pianista',
#   'muy',
#   'ameno',
#   'que',
#   'te',
#   'hace',
#   'pasar',
#   'una',
#   'cena',
#   'romantica',
#   'especialmente',
#   'si',
#   'vas',
#   'acompañado',
#   'de',
#   'alguien',
#   'especial',
#   '.'],
#  ['No',
#   'son',
#   'platos',
#   'rimbombantes',
#   '(',
#   'ya',
#   'varias',
#   'personas',
#   'me',
#   'han',
#   'dicho',
#   'que',
#   'es',
#   'mejor',
#   'la',
#   'comida',
#   'de',
#   'Alhama',
#   'de',
#   'Aragón',
#   ')',
#   ',',
#   'pero',
#   'se',
#   'dejan',
#   'comer',
#   'y',
#   'estaban',
#   'bien',
#   '.'],
#  ['En', 'total', ',', '190', 'euros', 'para', 'seis', 'personas', '.'],
#  ['Tardaron',
#   'mucho',
#   ',',
#   'mucho',
#   'ruido',
#   ',',
#   'comida',
#   'sin',
#   'gracia',
#   '.'],
#  ['La',
#   'comida',
#   'y',
#   'el',
#   'lugar',
#   'están',
#   'bien',
#   'pero',
#   'el',
#   'servicio',
#   'es',
#   'muy',
#   'lento',
#   '.'],
#  ['muy', 'bien', 'cortado', 'el', 'jamon', 'y', 'de', 'buena', 'calidad', '.'],
#  ['Luego', 'Salomillo', '.'],
#  ['Éramos', 'una', 'familia', 'celebrando', 'cumpleaños', '.'],
#  ['El',
#   'sitio',
#   'no',
#   'es',
#   'de',
#   'los',
#   'que',
#   'deslumbra',
#   'con',
#   'su',
#   'decoración',
#   'de',
#   'lujo',
#   'pero',
#   'tiene',
#   'esa',
#   'sobriedad',
#   'de',
#   'los',
#   'sitios',
#   'que',
#   'saben',
#   'que',
#   'no',
#   'les',
#   'hace',
#   'falta',
#   '.'],
#  ['La', 'verdad', 'comimos', 'muy', 'bien', ',', 'disfrutamos', '.'],
#  ['No',
#   'le',
#   'resultaba',
#   'nuestra',
#   'reserva',
#   'online',
#   ',',
#   'y',
#   'nos',
#   'comentaron',
#   'que',
#   'era',
#   'mejor',
#   'contactar',
#   'directamente',
#   'con',
#   'ellos',
#   '.'],
#  ['Hago',
#   'saber',
#   'que',
#   'no',
#   'tengo',
#   'nada',
#   'que',
#   'ver',
#   'con',
#   'sus',
#   'opiniones'],
#  ['Excelente', 'el', 'circuito', 'termal', '.'],
#  ['-',
#   'Jarrete',
#   'a',
#   'baja',
#   'temperatura',
#   'con',
#   'salsa',
#   'caramelizada',
#   'y',
#   'puré',
#   'trufado',
#   '.'],
#  ['muy', 'recomendable'],
#  ['Comida', 'casera', ',', 'y', 'todo', 'como', 'en', 'familia', '.'],
#  ['Fuimos',
#   'recomendados',
#   'a',
#   'cenar',
#   'en',
#   'Nochebuena',
#   'y',
#   'nos',
#   'llevamos',
#   'una',
#   'gran',
#   'decepción',
#   ':',
#   'no',
#   'sólo',
#   'las',
#   'materias',
#   'primas',
#   'dejaban',
#   'mucho',
#   'que',
#   'desear',
#   '(',
#   'revuelto',
#   'de',
#   'gambas',
#   'y',
#   'setas',
#   'de',
#   'bolsa',
#   'precongelada',
#   ')',
#   'sino',
#   'que',
#   'las',
#   'cantidades',
#   'eran',
#   'irrisorias',
#   'para',
#   'el',
#   'precio',
#   '.'],
#  ['Yo',
#   'pedí',
#   'una',
#   'mesa',
#   'bien',
#   'situada',
#   'y',
#   'atendieron',
#   'la',
#   'petición',
#   ',',
#   'nos',
#   'dieron',
#   'una',
#   'con',
#   'muy',
#   'buenas',
#   'vistas',
#   '.'],
#  ['Éramos', '3', 'adultos', '.'],
#  ['Personal',
#   'de',
#   'sala',
#   'muy',
#   'atento',
#   'y',
#   'alimentos',
#   'de',
#   'calidad',
#   'y',
#   'bien',
#   'cocinados',
#   '.'],
#  ['NO', 'LO', 'RECOMIENDO', 'EN', 'ABSOLUTO', '.'],
#  ['Escriba',
#   'aquí',
#   'su',
#   'comentario',
#   '…',
#   'Buena',
#   'relación',
#   'calidad',
#   '-',
#   'precio',
#   '.'],
#  ['Tranquilo',
#   'agradable',
#   'y',
#   'los',
#   'niños',
#   'no',
#   'molestan',
#   'con',
#   'un',
#   'acertado',
#   'menu',
#   'infantil',
#   'una',
#   'buena',
#   'elección',
#   'para',
#   'toda',
#   'la',
#   'familia',
#   '.'],
#  ['Tanto',
#   'el',
#   'ambiente',
#   'del',
#   'lugar',
#   'como',
#   'la',
#   'atencion',
#   'de',
#   'los',
#   'camareros',
#   'fue',
#   'impoluta',
#   ',',
#   'asi',
#   'que',
#   'salimos',
#   'con',
#   'una',
#   'magnifica',
#   'sensacion',
#   '.'],
#  ['Lo', 'recomiendo', 'totalmente'],
#  ['La',
#   'gente',
#   'que',
#   'ha',
#   'dado',
#   'su',
#   'opinion',
#   ',',
#   'que',
#   'son',
#   'amigos',
#   'o',
#   'familiares',
#   '?'],
#  ['Agradable',
#   'ambiente',
#   ',',
#   'muy',
#   'buen',
#   'servicio',
#   'y',
#   'exquisitos',
#   'platos',
#   '.'],
#  ['El',
#   'servicio',
#   'más',
#   'pendiente',
#   'de',
#   'una',
#   'cena',
#   'de',
#   'empresa',
#   ',',
#   'por',
#   'tanto',
#   'no',
#   'fue',
#   'bueno',
#   'el',
#   'servicio',
#   '.'],
#  ['Nos',
#   'sirvieron',
#   'un',
#   'aperitivo',
#   ',',
#   'tostadas',
#   'con',
#   'tomate',
#   '.'],
#  ['Los',
#   'postres',
#   ',',
#   'como',
#   'si',
#   'fuera',
#   'un',
#   'concurso',
#   'de',
#   'miniaturas',
#   '.'],
#  ['Por', 'malo', 'que', 'sea', ',', 'será', 'mejor', 'que', 'este', '.'],
#  ['En',
#   'lo',
#   'referente',
#   'a',
#   'calidad-precio',
#   'y',
#   'dentro',
#   'de',
#   'su',
#   'categoría',
#   ',',
#   'desde',
#   'mi',
#   'punto',
#   'de',
#   'vista',
#   ',',
#   'debe',
#   'ser',
#   'uno',
#   'de',
#   'los',
#   'restaurantes',
#   'de',
#   'referencia',
#   'de',
#   'Zaragoza',
#   '.'],
#  ['Recomendable', 'totalmente', '.'],
#  ['Debió',
#   'ser',
#   ',',
#   'al',
#   'leer',
#   'estos',
#   'comentarios',
#   'que',
#   'debimos',
#   'acudir',
#   'a',
#   'este',
#   'restaurante',
#   'en',
#   'un',
#   'mal',
#   'día',
#   '.'],
#  ['Desconozco',
#   'de',
#   'verdad',
#   ',',
#   'el',
#   'lugar',
#   'al',
#   'que',
#   'haceis',
#   'referencia',
#   'casi',
#   'todos',
#   ',',
#   'pero',
#   'el',
#   'sabado',
#   'por',
#   'la',
#   'noche',
#   'dia',
#   '21',
#   'de',
#   'enero',
#   'de',
#   '2012',
#   ',',
#   'estuvimos',
#   'cenando',
#   'un',
#   'gupo',
#   'de',
#   'amigos',
#   '(8',
#   'pax',
#   '.',
#   ')'],
#  ['Buena', 'relación', 'calidad', '/', 'precio', '.'],
#  ['El',
#   'precio',
#   'no',
#   'es',
#   'barato',
#   'pero',
#   'comparado',
#   'con',
#   'sitios',
#   'donde',
#   'te',
#   'van',
#   'empujando',
#   'de',
#   'mala',
#   'manera',
#   ',',
#   'merece',
#   'la',
#   'pena',
#   '.'],
#  ['¿',
#   'Cómo',
#   'vamos',
#   'a',
#   'pedir',
#   'un',
#   'vino',
#   'si',
#   'no',
#   'somos',
#   'adivinos',
#   'de',
#   'los',
#   'platos',
#   'que',
#   'nos',
#   'van',
#   'a',
#   'sacar',
#   '?',
#   'En',
#   'este',
#   'punto',
#   'fallan',
#   '.'],
#  ['El',
#   'arroz',
#   'caldoso',
#   'no',
#   'tenia',
#   'lo',
#   'suficiente',
#   'para',
#   'ser',
#   'un',
#   'buen',
#   'arroz',
#   '.'],
#  ['Tuvieron',
#   'un',
#   'detalle',
#   'al',
#   'cambiarme',
#   'la',
#   'parrillada',
#   'de',
#   'carne',
#   'por',
#   'una',
#   'parrillada',
#   'de',
#   'verduras',
#   '(',
#   'opción',
#   'vegetariana',
#   ')',
#   '.'],
#  ['No',
#   'importaba',
#   'mucho',
#   'que',
#   'fuera',
#   'del',
#   'grigo',
#   ',',
#   'dado',
#   'que',
#   'el',
#   'agua',
#   'de',
#   'la',
#   'zona',
#   'es',
#   'excelente',
#   ';',
#   'pero',
#   'por',
#   'ello',
#   'se',
#   'nos',
#   'facturó',
#   '2,50',
#   'euros',
#   '.'],
#  ['No',
#   'es',
#   'por',
#   'nada',
#   ',',
#   'pero',
#   'mira',
#   'que',
#   'hacéis',
#   'daño',
#   'los',
#   'presuntos',
#   'prescriptores',
#   ',',
#   'con',
#   'vuestra',
#   'presunta',
#   'experiencia',
#   'y',
#   'vuestro',
#   'presunto',
#   'buen',
#   'gusto',
#   '.'],
#  ['el', 'servicio', 'impecable', '.'],
#  ['Lo',
#   'han',
#   'repetido',
#   'en',
#   'varias',
#   'opiniones',
#   ':',
#   'el',
#   'ruido',
#   'es',
#   'insufrible',
#   '!',
#   '!'],
#  ['Para',
#   'mí',
#   'el',
#   'SERVICIO',
#   'de',
#   'este',
#   'restaurante',
#   'lo',
#   'valoro',
#   'como',
#   'de',
#   'los',
#   'mejores',
#   'porque',
#   'no',
#   'molestan',
#   '.'],
#  ['El', 'chocolate', 'de', 'los', 'postres', 'exquisito', '.'],
#  ['No',
#   'es',
#   'nada',
#   'barato',
#   'pero',
#   'ofrece',
#   'calidad',
#   'y',
#   'los',
#   'platos',
#   'están',
#   'bien',
#   'cocinados',
#   'y',
#   'con',
#   'elementos',
#   'frescos',
#   '.'],
#  ['Comimos',
#   'mi',
#   'marido',
#   'y',
#   'yo',
#   'en',
#   'el',
#   'restaurante',
#   'el',
#   'sábado',
#   'pasado',
#   ',',
#   'el',
#   'menú',
#   'temático',
#   'de',
#   'la',
#   'trufa',
#   'y',
#   'el',
#   'cabrito',
#   ',',
#   'es',
#   'estupendo',
#   ',',
#   'equilibrado',
#   ',',
#   'bueno',
#   'quizas',
#   'demasiado',
#   ',',
#   'pero',
#   'nosotros',
#   'somos',
#   'de',
#   'buen',
#   'comer',
#   'y',
#   'sabemos',
#   'apreciar',
#   'lo',
#   'bueno',
#   '.'],
#  ['Mas',
#   'que',
#   'otro',
#   '“',
#   'cachirulo',
#   '”',
#   'sugiero',
#   'al',
#   'autor',
#   'de',
#   'este',
#   'blog',
#   ',',
#   'la',
#   'marca',
#   '“',
#   'siempre',
#   'aciertas',
#   '”',
#   '.'],
#  ['Lugar', 'perfecto', '.'],
#  ['Muy', 'recomendable', '.'],
#  ['Como',
#   '2º',
#   'plato',
#   'yo',
#   'elegí',
#   'churrasco',
#   ',',
#   'que',
#   'estaba',
#   'sensacional',
#   ',',
#   'y',
#   'con',
#   'patatas',
#   'fritas',
#   'caseras',
#   '(',
#   'no',
#   'congeladas',
#   ')',
#   '.'],
#  ['Buen', 'comer', 'y', 'muy', 'buen', 'servicio', '.'],
#  ['he',
#   'ido',
#   'varias',
#   'veces',
#   'pero',
#   'el',
#   'sitio',
#   'es',
#   'para',
#   'turistas',
#   'y',
#   'aunque',
#   'la',
#   'calidad',
#   'es',
#   'buena',
#   'el',
#   'precio',
#   'es',
#   'exagerado',
#   'y',
#   'el',
#   'servicio',
#   'deja',
#   'mucho',
#   'que',
#   'desear',
#   ',',
#   'sobretodo',
#   'en',
#   'cuanto',
#   'a',
#   'las',
#   'reservas',
#   '.'],
#  ['En',
#   'la',
#   'mesa',
#   'que',
#   'nos',
#   'prepararon',
#   'caía',
#   'aigua',
#   'del',
#   'techo',
#   ',',
#   'y',
#   'estabamos',
#   'pegados',
#   'a',
#   'la',
#   'caleffacción',
#   '.'],
#  ['Los',
#   'camareros',
#   'son',
#   'atentos',
#   'y',
#   'muy',
#   'amables',
#   ',',
#   'el',
#   'menú',
#   'calçotada',
#   'es',
#   'interminable',
#   '!'],
#  ['Lo', 'recomiendo', ',', 'no', 'les', 'dejara', 'indiferente', '.'],
#  ['Si',
#   'tienes',
#   'cuidado',
#   'con',
#   'lo',
#   'que',
#   'pides',
#   'puedes',
#   'comer',
#   'muy',
#   'bien',
#   'sin',
#   'dejarte',
#   'la',
#   'cartera',
#   '.']]

# %%
## predicted = []
file_path_dev_p2_out = 'Data/ES/dev.p2.out'

# Open the output file for writing using UTF-8 encoding
with open(file_path_dev_p2_out, 'w', encoding='utf-8') as file:
    for s in range(len(dev_in_data)):
        for wi in range(len(dev_in_data[s])):
            line = dev_in_data[s][wi]+" "+predicted_tags_viterbi[s][wi]
            if line != "\n":
                file.write(line + '\n')
            else:
                file.write(line)
        file.write('\n')

# %% [markdown]
# # Part 4

# %% [markdown]
# We can modify the approach by using an n-th order HMM, whereby the HMM can depend on not only the current state but also the previous n-states. In this case, we have adopted n=2.

# %%
#set to RU/ES
lang = 'RU'
#set to test/dev
flag = 'test'


if(flag=='test'):
    dev_in_data = load_data(f'Test/{lang}/{flag}.in')
    dev_out_data = f'Test/{lang}/{flag}.p4.out'
    

elif(flag=='dev'):
    dev_in_data = load_data(f'Data/{lang}/{flag}.in')
    dev_out_data = f'Data/{lang}/{flag}.p4.out'
    with open(f'Data/{lang}/dev.out', 'r', encoding='utf-8') as f:
        dev_tags_actual = [sentence.split() for sentence in f.read().strip().split('\n\n')]

# Adjusting the paths for ES and RU datasets
train_data = load_data(f'Data/{lang}/train')

# %%
states = {}
observations = {}

for sentence in train_data:
    for line in sentence:
        word, tag = line.strip().split(maxsplit=1)
        states[tag] = states.get(tag, 0) + 1
        if tag not in observations:
            observations[tag] = {}
        observations[tag][word] = observations[tag].get(word, 0) + 1

state_list = list(states.keys())

# %%
from collections import defaultdict

def compute_probabilities(data, state_list):
    # Initialize counts
    start_count = defaultdict(int)
    transition_count = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    emission_count = defaultdict(lambda: defaultdict(int))

    # Populate counts
    for sentence in data:
        if len(sentence) < 3:  # Skip sentences that are too short
            continue

        # Splitting and extracting the word and state for first two words/states
        word1, state1 = sentence[0].strip().split()
        word2, state2 = sentence[1].strip().split()
        start_count[state1] += 1
        emission_count[state1][word1] += 1
        emission_count[state2][word2] += 1

        # Rest of the sentence
        for i in range(2, len(sentence)):
            word3, state3 = sentence[i].strip().split(maxsplit=1)
            transition_count[state1][state2][state3] += 1
            emission_count[state3][word3] += 1
            state1, state2 = state2, state3

    # Convert counts to probabilities
    # Start transition probabilities
    start_transition_prob = {state: count / sum(start_count.values()) for state, count in start_count.items()}

    # Transition probabilities
    transition_prob = {}
    for s1, s1_dict in transition_count.items():
        transition_prob[s1] = {}
        for s2, s2_dict in s1_dict.items():
            transition_prob[s1][s2] = {}
            for s3, count in s2_dict.items():
                total = sum(s2_dict.values())
                transition_prob[s1][s2][s3] = count / total if total != 0 else 0.0

    # Emission probabilities
    emission_prob = {}
    for state, word_count in emission_count.items():
        emission_prob[state] = {}
        total = sum(word_count.values())
        for word, count in word_count.items():
            emission_prob[state][word] = count / total

    return start_transition_prob, transition_prob, emission_prob

# %%
state_list = list(states.keys())
start_transition_prob, transition_prob, emission_prob = compute_probabilities(train_data, state_list)

# %%
transition_prob
# Out:
# {'B-positive': {'O': {'O': 0.9153963414634146,
#    'B-positive': 0.08307926829268293,
#    'B-neutral': 0.001524390243902439},
#   'I-positive': {'O': 0.6131805157593123,
#    'I-positive': 0.3839541547277937,
#    'B-positive': 0.0028653295128939827},
#   'B-positive': {'O': 1.0}},
#  'O': {'O': {'O': 0.948982402448355,
#    'B-positive': 0.03727620504973221,
#    'B-negative': 0.010130068859984697,
#    'B-neutral': 0.003550114766641163,
#    '.. O': 3.0604437643458305e-05,
#    '... O': 3.0604437643458305e-05},
#   'B-positive': {'I-positive': 0.20557029177718833,
#    'O': 0.7924403183023873,
#    'B-positive': 0.001989389920424403},
#   'B-negative': {'I-negative': 0.1931216931216931, 'O': 0.8068783068783069},
#   'B-neutral': {'O': 0.8591549295774648, 'I-neutral': 0.14084507042253522},
#   '.. O': {'O': 1.0},
#   '... O': {'O': 1.0}},
#  'I-positive': {'O': {'O': 0.8397212543554007,
#    'B-positive': 0.1602787456445993},
#   'I-positive': {'O': 0.5425101214574899, 'I-positive': 0.4574898785425101},
#   'B-positive': {'I-positive': 1.0}},
#  'B-negative': {'I-negative': {'I-negative': 0.41975308641975306,
#    'O': 0.5802469135802469},
#   'O': {'O': 0.9642857142857143,
#    'B-negative': 0.03273809523809524,
#    'B-positive': 0.002976190476190476}},
#  'I-negative': {'I-negative': {'O': 0.576271186440678,
#    'I-negative': 0.423728813559322},
#   'O': {'O': 0.9726027397260274, 'B-negative': 0.0273972602739726}},
#  'B-neutral': {'O': {'O': 0.9644970414201184,
#    'B-neutral': 0.03550295857988166},
#   'I-neutral': {'I-neutral': 0.6428571428571429, 'O': 0.35714285714285715}},
#  'I-neutral': {'I-neutral': {'O': 0.45, 'I-neutral': 0.55},
#   'O': {'O': 0.9230769230769231, 'B-neutral': 0.07692307692307693}},
#  '.. O': {'O': {'B-positive': 1.0}},
#  '... O': {'O': {'O': 1.0}}}

# %%
def viterbi(obs, states, start_p, trans_p, emit_p):
    # Initialize the Viterbi matrix. 
    V = [{}]

    # Initialize the first column of the matrix with the start probabilities
    for st in states:
        V[0][st] = {"prob": start_p.get(st, 0) * emit_p[st].get(obs[0], 0), "prev": None}

    # Main loop through the observations updating the Viterbi matrix
    for t in range(1, len(obs)):
        V.append({})
        for st in states:
            # For each state, find the maximum transition probability 
            # considering all possible previous state combinations.
            max_trans_prob, prev_st1_max, prev_st2_max = max(
                (V[t-1][prev_st1]["prob"] * trans_p[prev_st1].get(prev_st2, {}).get(st, 0), prev_st1, prev_st2)
                for prev_st1 in states for prev_st2 in states
            )

            # Multiply the max transition probability with emission probability
            max_prob = max_trans_prob * emit_p[st].get(obs[t], 0)

            # Store the maximum probability and previous state information
            V[t][st] = {"prob": max_prob, "prev": (prev_st1_max, prev_st2_max)}

    # Now, backtrack to find the most probable sequence of states
    opt = []

    # Find the state with the maximum probability for the last observation
    max_prob = max(value["prob"] for value in V[-1].values())
    previous = None

    for st, data in V[-1].items():
        if data["prob"] == max_prob:
            opt.append(st)
            previous = st
            break

    # Backtrack through the Viterbi matrix to find the sequence of states
    for t in range(len(V) - 2, -1, -1):
        opt.insert(0, V[t + 1][previous]["prev"][1])
        previous = V[t + 1][previous]["prev"][1]

    # Return the most probable sequence of states
    return opt

# %%
predicted_tags_viterbi = [viterbi([word.split()[0] for word in sentence], state_list, start_transition_prob, transition_prob, emission_prob) for sentence in dev_in_data]

# %%
def extract_entities_from_tags(tags):
    entities = []
    entity = []
    for tag in tags:
        if tag.startswith("B-"):
            if entity:
                entities.append(tuple(entity))
                entity = []
            entity.append(tag)
        elif tag.startswith("I-"):
            entity.append(tag)
        else:
            if entity:
                entities.append(tuple(entity))
                entity = []
    if entity:
        entities.append(tuple(entity))
    return set(entities)

TP = 0
FP = 0
FN = 0


if(flag=='dev'):
    for pred, actual in zip(predicted_tags_viterbi, dev_tags_actual):
        predicted_entities = extract_entities_from_tags(pred)
        actual_entities = extract_entities_from_tags(actual)
        TP += len(predicted_entities.intersection(actual_entities))
        FP += len(predicted_entities - actual_entities)
        FN += len(actual_entities - predicted_entities)

    if TP + FP == 0:
        precision = 1.0  # or 0.0, depending on how you want to define it in this case
    else:
        precision = TP / (TP + FP)

    if TP + FN == 0:
        recall = 1.0  # or 0.0
    else:
        recall = TP / (TP + FN)

    if precision + recall == 0:
        f_score = 0.0
    else:
        f_score = 2 * precision * recall / (precision + recall)


    print("Precision:", precision)
    print("Recall:", recall)
    print("F-score:", f_score)

# %%
## predicted = []

# Open the output file for writing using UTF-8 encoding
with open(dev_out_data, 'w', encoding='utf-8') as file:
    for s in range(len(dev_in_data)):
        for wi in range(len(dev_in_data[s])):
            line = dev_in_data[s][wi]+" "+predicted_tags_viterbi[s][wi]
            if line != "\n":
                file.write(line + '\n')
            else:
                file.write(line)
        file.write('\n')
